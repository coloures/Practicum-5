# %% [markdown]
# Домашнее задание по "Практикуму по программированию" за 5 семестр.
#
# Выполнил: Биндюк Глеб Игоревич
#
# Группа: МО-231
#
# Проверил: Бугаенко Иван Евгеньевич

# %% [markdown]
# Разработать модель прогнозирования изменений «Гармонии Бессмертия» на основе данных, собираемых командой (ведьмаками, чародейками и Логиком), чтобы своевременно предотвратить катастрофу.

# %% [markdown]
# | № | Название                       | Описание                                                                                                                                   | Тип данных     |
# |---|--------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------|----------------|
# | 1 | Вектор Мощи                    | Позиция магического механизма, управляющего интенсивностью перехода через портал.                                                          | Вещественный   |
# | 2 | Скорость перехода через портал | Скорость, с которой портал перемещает объект через пространство.                                                                           | Вещественный   |
# | 3 | Приток Силы Потока             | Поток магической силы, текущий через ядро портала, обеспечивая его стабильную работу.                                                      | Вещественный   |
# | 4 | Ритм магического ядра          | Число оборотов магического ядра портала в минуту.                                                                                          | Вещественный   |
# | 5 | Поток Энергий                  | Число оборотов генератора эфира, преобразующего внешнюю энергию в магическую.                                                              | Вещественный   |
# | 6 | Сила Левого Потока             | Мощность магического потока, текущего через левую сторону портала, поддерживая его баланс.                                                 | Вещественный   |
# | 7 | Сила Правого Потока            | Мощность магического потока, текущего через правую сторону портала, обеспечивая равномерное распределение энергии.                         | Вещественный   |
# | 8 | Пламя Стихий                   | Температура магической энергии, исходящей из высокого магического источника портала, в градусах Цельсия.                                   | Вещественный   |
# | 9 | Температура вдоха Истока       | Температура воздуха, входящего в магический ускоритель портала, в градусах Цельсия.                                                        | Вещественный   |
# | 10| Температура выхода Истока      | Температура воздуха, исходящего из магического ускорителя портала, в градусах Цельсия.                                                     | Вещественный   |
# | 11| Приток давления Выдоха Истока  | Давление магического потока на выходе из магического источника высокого давления.                                                          | Вещественный   |
# | 12| Давление вдоха Истока          | Давление воздуха, входящего в магический ускоритель.                                                                                       | Вещественный   |
# | 13| Давление выхода Истока         | Давление воздуха, исходящего из магического ускорителя.                                                                                    | Вещественный   |
# | 14| Древний Ветер                  | Давление древней магической энергии, покидающей портал в виде выхлопного потока.                                                           | Вещественный   |
# | 15| Печать Чародея                 | Параметр управления магическим впрыском в сердце портала, выраженный в процентах.                                                          | Вещественный   |
# | 16| Эмульсия Истока                | Количество магического топлива, подпитывающего портал.                                                                                     | Вещественный   |
# | 17| Дыхание Истока                 | Коэффициент, отображающий степень угасания магического ускорителя.                                                                         | Вещественный   |
# | 18| Гармония Бессмертия            | Коэффициент, указывающий на состояние магического ядра портала и его стабильность, требующий магического восстановления в случае снижения. | Вещественный   |
# | 19| Тип Вектора Мощи               | Метка типа позиции магического механизма                                                                                                   | Категориальный |
# | 20| Номер пометки                  | Уникальный номер записи о работе портала в блокноте.                                                                                       | Целочисленный  |

# %% [markdown]
# Целевой признак - Гармония Бессмертия

# %% [markdown]
# Дополнительно:
#
# Для определения общей мощности потоков сначала сложите значения **«Силы Левого Потока»** и **«Силы Правого Потока»**, чтобы получить представление о совокупной мощности. Для более полной картины суммарной силы всех потоков дополнительно объедините **«Силу Левого Потока»**, **«Силу Правого Потока»** и **«Приток Силы Потока»**.
#
# Общую силу ядра можно оценить, умножив **«Ритм магического ядра»** на **«Приток Силы Потока»**, что даст показатель общей мощности ядра. Общее давление на выходе можно рассчитать, сложив значения **«Притока давления Выдоха Истока»** и **«Давления выхода Истока»**.
#
# Магическую производительность определяет отношение **«Скорости перехода через портал»** к **«Эмульсии Истока»** — это покажет, насколько эффективно топливо поддерживает скорость перехода. Эффективность самого ядра можно вычислить, разделив его общую силу на **«Эмульсию Истока»**.
#
# Для расчёта магической мощности потребуется учесть **«Эмульсию Истока»**, общее давление и разницу между **«Пламенем Стихий»** и **«Температурой вдоха Истока»**. (Использовать нельзя - Температура вдоха Истока уберется из-за огромного количества отсутствующий значений)
#
# Оценить степень износа магических источников поможет отношение **«Дыхания Истока»** к **«Гармонии Бессмертия»**. (Использовать нельзя - утечка данных)
#
# Абсолютное значение разницы между **«Дыханием Истока»** и **«Гармонией Бессмертия»** отразит расхождения в стабильности магии, а баланс угасания можно определить, разделив разницу между **«Дыханием Истока»** и **«Гармонией Бессмертия»** на **«Скорость перехода через портал»**. (Нельзя использовать - утечка данных)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from scipy.stats import entropy
from pyod.models.iforest import IsolationForest
from pyod.models.ocsvm import OCSVM
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.neighbors import NearestNeighbors

# %%
seed = 5
np.random.seed(seed)

# %% [markdown]
# # 1. Предварительная обработка данных

# %% [markdown]
# ## 1.1. Чтение и загрузка данных

# %%
df = pd.read_csv('portal_data.csv', encoding='cp1251', sep='|')

# %%
df
# Out:
#        Вектор Мощи Скорость перехода через портал  Приток Силы Потока  \
# 0            1.138                        1.54332             289.964
# 1            2.088                              -            6960.180
# 2            3.144             4.6299600000000005            8379.229
# 3            4.161                        6.17328           14724.395
# 4            5.140                         7.7166           21636.432
# ...            ...                            ...                 ...
# 11929        5.140                         7.7166           21624.934
# 11930        6.175                        9.25992           29763.213
# 11931        7.148                       10.80324           39003.867
# 11932        8.206                       12.34656           50992.579
# 11933        9.300                       13.88988           72775.130
#
#        Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %% [markdown]
# Выводим датафрейм (данные) для "первичной" проверки их загрузки.

# %% [markdown]
# ## 1.2. Первичный анализ данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11934 entries, 0 to 11933
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Вектор Мощи                     11934 non-null  float64
#  1   Скорость перехода через портал  11934 non-null  object
#  2   Приток Силы Потока              11934 non-null  float64
#  3   Ритм магического ядра           11934 non-null  float64
#  4   Поток Энергий                   11934 non-null  float64
#  5   Сила Левого Потока              11934 non-null  float64
#  6   Сила Правого Потока             11934 non-null  float64
#  7   Пламя Стихий                    11934 non-null  float64
#  8   Температура вдоха Истока        11934 non-null  int64
#  9   Температура выдоха Истока       11934 non-null  object
#  10  Приток давления Выдоха Истока   11934 non-null  float64
#  11  Давление вдоха Истока           11934 non-null  object
# ...

# %% [markdown]
# Посмотрим типы данных (которые исходные)

# %%
df.describe()
# Out:
#         Вектор Мощи  Приток Силы Потока  Ритм магического ядра  Поток Энергий  \
# count  11934.000000        11934.000000           11934.000000   11934.000000
# mean       5.166667        27247.498685             223.711688    8200.947312
# std        2.626388        22148.613155              81.061874    1091.315507
# min        1.138000          253.547000             136.939406    6589.002000
# 25%        3.144000         8375.883750             145.220958    7058.324000
# 50%        5.140000        21630.659000             201.514947    8482.081500
# 75%        7.148000        39001.426750             280.447777    9132.606000
# max        9.300000        72784.872000             372.879926    9797.103000
#
#        Сила Левого Потока  Сила Правого Потока  Пламя Стихий  \
# count        11934.000000         11934.000000  11934.000000
# mean           227.335768           227.335768    735.495446
# std            200.495889           200.495889    173.680552
# ...

# %% [markdown]
# Заметим, что признаков в describe 15, а не 20 (изначально)

# %%
set(df.columns).symmetric_difference(df.describe().columns)
# Out:
# {'Давление вдоха Истока',
#  'Древний Ветер',
#  'Скорость перехода через портал',
#  'Температура выдоха Истока',
#  'Тип Вектора Мощи'}

# %% [markdown]
# То есть у этих признаков может и не быть числовых значений вообще (не обязательно).

# %%
df['Давление вдоха Истока'].unique()
# Out:
# array(['Не определено', '1.394603'], dtype=object)

# %%
len(df[df['Давление вдоха Истока'] != 'Не определено']) / len(df)
# Out:
# 0.20437405731523378

# %% [markdown]
# Около 20,4 % обладают одним и тем же Давление вдоха Истока, а остальные вообще не обладают данным признаком. Целесообразно просто **удалить** данный признак!

# %%
df['Древний Ветер'].unique()
# Out:
# array(['-', '1.019', '1.026', '1.03', '1.02', '1.04', '1.022', '1.035',
#        '1.049', '1.041', '1.023', '1.05', '1.036', '1.042', '1.031',
#        '1.027', '1.051', '1.021', '1.052', '1.043'], dtype=object)

# %%
len(df[df['Древний Ветер'] == '-']) / len(df)
# Out:
# 0.7999832411597118

# %% [markdown]
# Видим, что и у параметра **Древний ветер** похожая проблема. Поэтому, чтобы не захломлять и так большое количество параметров - **УДАЛИМ** его!

# %%
df['Скорость перехода через портал'].unique()
# Out:
# array(['1.54332', '-', '4.6299600000000005', '6.17328', '7.7166',
#        '9.25992', '10.80324', '12.34656', '13.88988', '3.08664'],
#       dtype=object)

# %%
len(df[df['Скорость перехода через портал'] == '-']) / len(df)
# Out:
# 0.1008044243338361

# %%
print(df['Скорость перехода через портал'].value_counts(dropna=False))
# Out:
# Скорость перехода через портал
# 12.34656              1204
# -                     1203
# 1.54332               1202
# 7.7166                1200
# 13.88988              1199
# 3.08664               1199
# 9.25992               1187
# 10.80324              1186
# 6.17328               1180
# 4.6299600000000005    1174
# Name: count, dtype: int64

# %% [markdown]
# Убирать данный признак не будем. Просто заполним значения '-' медианой. **Изменено: мы посмотрим на гистограмме как это влияет на распределение**

# %% [markdown]
# Перед тем как определять, чем же заполнить "Скорость перехода через портал" - выполним все остальные действия, не зависящие от этого признака.

# %%
df['Температура выдоха Истока'].unique()
# Out:
# array(['-', '581.658', '645.642', ..., '680.557', '628.95', '680.393'],
#       shape=(2369,), dtype=object)

# %%
len(df[df['Температура выдоха Истока'] == '-']) / len(df)
# Out:
# 0.7999832411597118

# %% [markdown]
# Очень много пропущенных значений. Признак удаляем

# %%
df['Тип Вектора Мощи'].unique()
# Out:
# array(['Слабый', 'Ниже среднего', 'Выше среднего', 'Сильный'],
#       dtype=object)

# %% [markdown]
# Тут явный категориальный признак - используем hot-encoding

# %%
new_df = df

# %%
for col in new_df.columns:
    print(f"{new_df[col].unique()} для столбца {col}")
# Out:
# [1.138 2.088 3.144 4.161 5.14  6.175 7.148 8.206 9.3  ] для столбца Вектор Мощи
# ['1.54332' '-' '4.6299600000000005' '6.17328' '7.7166' '9.25992'
#  '10.80324' '12.34656' '13.88988' '3.08664'] для столбца Скорость перехода через портал
# [  289.964  6960.18   8379.229 ... 39003.867 50992.579 72775.13 ] для столбца Приток Силы Потока
# [141.31815762 144.11176652 145.22085345 ... 140.80806769 147.29891227
#  140.89425205] для столбца Ритм магического ядра
# [6677.38  6828.469 7111.811 ... 9120.889 9300.274 9742.95 ] для столбца Поток Энергий
# [ 7.584 28.204 60.358 ... 22.335 10.692 22.478] для столбца Сила Левого Потока
# [ 7.584 28.204 60.358 ... 22.335 10.692 22.478] для столбца Сила Правого Потока
# [ 464.006  635.401  606.002 ...  796.457  892.945 1038.411] для столбца Пламя Стихий
# [736] для столбца Температура вдоха Истока
# ['-' '581.658' '645.642' ... '680.557' '628.95' '680.393'] для столбца Температура выдоха Истока
# ...

# %% [markdown]
# Замечаем, что Температура вдоха Истока - признак, в котором присутствует одно уникальное значение - удаляем признак!

# %%
new_df.drop(columns=['Номер пометки','Давление вдоха Истока','Древний Ветер','Температура выдоха Истока', 'Температура вдоха Истока'], inplace=True)

# %%
new_df.columns
# Out:
# Index(['Вектор Мощи', 'Скорость перехода через портал', 'Приток Силы Потока',
#        'Ритм магического ядра', 'Поток Энергий', 'Сила Левого Потока',
#        'Сила Правого Потока', 'Пламя Стихий', 'Приток давления Выдоха Истока',
#        'Давление выдоха Истока', 'Печать Чародея', 'Эмульсия Истока',
#        'Дыхание Истока', 'Гармония Бессмертия', 'Тип Вектора Мощи'],
#       dtype='object')

# %% [markdown]
# Подытожим:
#
# **Номер пометки** - является ID - удаляем;
#
# **Давление вдоха Истока** - ОЧЕНЬ много пустых значений - удаляем;
#
# **Древний Ветер** - ОЧЕНЬ много пустых значений - удаляем;
#
# **Температура выдоха Истока** - ОЧЕНЬ много пустых значений - удаляем;

# %% [markdown]
# Конечно, преобразуем другие типы данных чтобы датасет не занимал так много места.
#
# Параметры, полученные из других просто добавим в новый датасет. Убирать исходные признаки (участвовашие в формулах) пока что не будем.

# %% [markdown]
# ## 1.3. Кодирование категориальных признаков

# %% [markdown]
# Поскольку категориальных признаков немного (один) и мы решили использовать "самый банальный" hot-encoding, то сделаем это как можно раньше, чтобы потом к этому не возвращаться уже.

# %%
new_df = pd.get_dummies(new_df, columns=['Тип Вектора Мощи'], drop_first=True)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11934 entries, 0 to 11933
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Вектор Мощи                     11934 non-null  float64
#  1   Скорость перехода через портал  11934 non-null  object
#  2   Приток Силы Потока              11934 non-null  float64
#  3   Ритм магического ядра           11934 non-null  float64
#  4   Поток Энергий                   11934 non-null  float64
#  5   Сила Левого Потока              11934 non-null  float64
#  6   Сила Правого Потока             11934 non-null  float64
#  7   Пламя Стихий                    11934 non-null  float64
#  8   Приток давления Выдоха Истока   11934 non-null  float64
#  9   Давление выдоха Истока          11934 non-null  float64
#  10  Печать Чародея                  11934 non-null  float64
#  11  Эмульсия Истока                 11934 non-null  float64
# ...

# %% [markdown]
# ## 1.4. Разделение выборки на обучающую и тестовую выборки

# %%
train_df, test_df = train_test_split(new_df, shuffle=True, random_state=seed, test_size=0.20)

X_train, X_test = train_df.drop(columns='Гармония Бессмертия'), test_df.drop(columns='Гармония Бессмертия')
y_train, y_test = train_df['Гармония Бессмертия'], test_df['Гармония Бессмертия']

# %% [markdown]
# ## 1.5. Обработка вещественных признаков (заполнение пропусков)

# %%
X_test['Скорость перехода через портал'] = pd.to_numeric(X_test['Скорость перехода через портал'], errors='coerce')
X_train['Скорость перехода через портал'] = pd.to_numeric(X_train['Скорость перехода через портал'], errors='coerce')

# %%
temp_df = X_train['Скорость перехода через портал']
temp_df.unique()
# Out:
# array([12.34656,      nan,  7.7166 , 10.80324,  6.17328,  1.54332,
#         4.62996,  9.25992, 13.88988,  3.08664])

# %%
temp_df.hist(bins= 25)
# Out:
# <Axes: >

# %% [markdown]
# Распределение значений "Скорости перехода через портал" без учёта nan значений

# %%
temp_med = temp_df.fillna(temp_df.dropna(axis=0).median())

# %%
temp_med.hist(bins = 25)
# Out:
# <Axes: >

# %% [markdown]
# Nan заменяем на медиану

# %% [markdown]
# Используем KL-дивергенцию с равномерным распределением

# %%
data1 = temp_med.dropna()
p1, _ = np.histogram(data1, bins=25, density=False)
p1 = p1 / p1.sum()
data2 = X_train['Скорость перехода через портал'].dropna()
p2, _ = np.histogram(data2, bins=25, density=False)
p2 = p2 / p2.sum()  
kl = entropy(p1, p2)  #  Сравниваем распределения
kl
# Out:
# np.float64(0.03335084383851507)

# %% [markdown]
# Распределения почти совпадают - хороший результат!

# %%
temp_mean = temp_df.fillna(temp_df.dropna(axis=0).mean())

# %%
temp_mean.hist(bins = 25)
# Out:
# <Axes: >

# %% [markdown]
# Заполнение nan средним

# %%
data1 = temp_mean.dropna()
p1, _ = np.histogram(data1, bins=25, density=False)
p1 = p1 / p1.sum()
data2 = X_train['Скорость перехода через портал'].dropna()
p2, _ = np.histogram(data2, bins=25, density=False)
p2 = p2 / p2.sum()  
kl = entropy(p1, p2)  #  Сравниваем распределения
kl
# Out:
# np.float64(0.03335084383851507)

# %% [markdown]
# Результат тот же самый => можно использовать любой

# %% [markdown]
# Лично я выбираю медианное значение, поскольку оно легче всего достается и является "классическим" решением в таких ситуациях.

# %%
replacer = X_train['Скорость перехода через портал'].median()

# %%
X_train['Скорость перехода через портал'] = X_train['Скорость перехода через портал'].fillna(replacer)
X_test['Скорость перехода через портал'] = X_test['Скорость перехода через портал'].fillna(replacer)

# %%
for col in X_train.columns:
    print(f"{(X_train[col].isnull().sum() / len(X_train)) * 100} для столбца {col}")
# Out:
# 0.0 для столбца Вектор Мощи
# 0.0 для столбца Скорость перехода через портал
# 0.0 для столбца Приток Силы Потока
# 0.0 для столбца Ритм магического ядра
# 0.0 для столбца Поток Энергий
# 0.0 для столбца Сила Левого Потока
# 0.0 для столбца Сила Правого Потока
# 0.0 для столбца Пламя Стихий
# 0.0 для столбца Приток давления Выдоха Истока
# 0.0 для столбца Давление выдоха Истока
# 0.0 для столбца Печать Чародея
# 0.0 для столбца Эмульсия Истока
# 0.0 для столбца Дыхание Истока
# 0.0 для столбца Тип Вектора Мощи_Ниже среднего
# 0.0 для столбца Тип Вектора Мощи_Сильный
# 0.0 для столбца Тип Вектора Мощи_Слабый

# %%
for col in X_test.columns:
    print(f"{(X_test[col].isnull().sum() / len(X_test)) * 100} для столбца {col}")
# Out:
# 0.0 для столбца Вектор Мощи
# 0.0 для столбца Скорость перехода через портал
# 0.0 для столбца Приток Силы Потока
# 0.0 для столбца Ритм магического ядра
# 0.0 для столбца Поток Энергий
# 0.0 для столбца Сила Левого Потока
# 0.0 для столбца Сила Правого Потока
# 0.0 для столбца Пламя Стихий
# 0.0 для столбца Приток давления Выдоха Истока
# 0.0 для столбца Давление выдоха Истока
# 0.0 для столбца Печать Чародея
# 0.0 для столбца Эмульсия Истока
# 0.0 для столбца Дыхание Истока
# 0.0 для столбца Тип Вектора Мощи_Ниже среднего
# 0.0 для столбца Тип Вектора Мощи_Сильный
# 0.0 для столбца Тип Вектора Мощи_Слабый

# %% [markdown]
# Теперь поменяем типы данных так, чтобы данные занимали как можно меньше места.

# %%
for i in [x for x in X_train.columns if x not in ['Приток Силы Потока','Тип Вектора Мощи_Ниже среднего','Тип Вектора Мощи_Сильный','Тип Вектора Мощи_Слабый']]:
    X_train[i] = X_train[i].astype('float32')

# %%
for i in [x for x in X_test.columns if x not in ['Приток Силы Потока','Тип Вектора Мощи_Ниже среднего','Тип Вектора Мощи_Сильный','Тип Вектора Мощи_Слабый']]:
    X_test[i] = X_test[i].astype('float32')

# %%
X_train['Приток Силы Потока'] = X_train['Приток Силы Потока'].astype('float32')
X_test['Приток Силы Потока'] = X_test['Приток Силы Потока'].astype('float32')

# %%
for col in ['Тип Вектора Мощи_Ниже среднего', 'Тип Вектора Мощи_Сильный', 'Тип Вектора Мощи_Слабый']:
    X_train[col] = X_train[col].astype('int16')
    X_test[col] = X_test[col].astype('int16')

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9547 entries, 1996 to 2915
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Вектор Мощи                     9547 non-null   float32
#  1   Скорость перехода через портал  9547 non-null   float32
#  2   Приток Силы Потока              9547 non-null   float32
#  3   Ритм магического ядра           9547 non-null   float32
#  4   Поток Энергий                   9547 non-null   float32
#  5   Сила Левого Потока              9547 non-null   float32
#  6   Сила Правого Потока             9547 non-null   float32
#  7   Пламя Стихий                    9547 non-null   float32
#  8   Приток давления Выдоха Истока   9547 non-null   float32
#  9   Давление выдоха Истока          9547 non-null   float32
#  10  Печать Чародея                  9547 non-null   float32
#  11  Эмульсия Истока                 9547 non-null   float32
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2387 entries, 9078 to 4862
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Вектор Мощи                     2387 non-null   float32
#  1   Скорость перехода через портал  2387 non-null   float32
#  2   Приток Силы Потока              2387 non-null   float32
#  3   Ритм магического ядра           2387 non-null   float32
#  4   Поток Энергий                   2387 non-null   float32
#  5   Сила Левого Потока              2387 non-null   float32
#  6   Сила Правого Потока             2387 non-null   float32
#  7   Пламя Стихий                    2387 non-null   float32
#  8   Приток давления Выдоха Истока   2387 non-null   float32
#  9   Давление выдоха Истока          2387 non-null   float32
#  10  Печать Чародея                  2387 non-null   float32
#  11  Эмульсия Истока                 2387 non-null   float32
# ...

# %% [markdown]
# ## 1.6. Детекция выбросов и аномалий в данных

# %%
combined_train_data = pd.concat([X_train, y_train], axis = 1)

# %%
exclude_cols = ['Гармония Бессмертия', 'Тип Вектора Мощи_Ниже среднего', 'Тип Вектора Мощи_Сильный', 'Тип Вектора Мощи_Слабый']

# %%
len(combined_train_data.columns)
# Out:
# 17

# %%
cols_to_plot = combined_train_data.columns.difference(exclude_cols)

# %%
for col in cols_to_plot:
    plt.figure(figsize=(6, 4))
    plt.boxplot(combined_train_data[col].dropna(), vert=True, patch_artist=True)
    plt.title(f'Boxplot: {col}')
    plt.ylabel(col)
    plt.grid(True, axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# Заметим, что особых смещений в данных нет (разве что незначительная в паре признаков - будем считать, что сильного влияния она не вносит). По поводу потенциальных выбросов - они есть. В признаке 'Печать Чародея' присутствуют возможные выбросы. Поэтому в них имеет смысл использовать IQR или Robust Z-score.

# %%
for col in cols_to_plot:
    plt.figure(figsize=(6, 4))
    plt.hist(combined_train_data[col].dropna(), bins=30, color='steelblue', edgecolor='black', alpha=0.7)
    plt.title(f'Гистограмма: {col}')
    plt.xlabel(col)
    plt.ylabel('Частота')
    plt.grid(True, axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Заметим, что в некоторых гистограммах есть несколько мод (пик), что может означать наличие скрытых подгрупп.

# %% [markdown]
# В признаке 'Печать Чародея' присутствуют возможные выбросы. Поэтому в них имеет смысл использовать IQR или Robust Z-score. *Для удаления мы выберем те строки, которые присутствуют как в IQR выбросах, так и в Z-score выбросах.*

# %%
columns = ['Печать Чародея']

# %%
combined_train_data_outliers = pd.DataFrame(columns=combined_train_data.columns)
for column in columns:
    Q1 = combined_train_data[column].quantile(0.25)
    Q3 = combined_train_data[column].quantile(0.75)
    IQR = Q3 - Q1

    # Границы выбросов
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # только выбросы
    combined_train_data_outliers = pd.concat([combined_train_data_outliers, combined_train_data[(combined_train_data[column] < lower_bound) | (combined_train_data[column] > upper_bound)]])
# Out:
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_103540\1628806345.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_train_data_outliers = pd.concat([combined_train_data_outliers, combined_train_data[(combined_train_data[column] < lower_bound) | (combined_train_data[column] > upper_bound)]])

# %%
combined_train_data_outliers
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 2213          9.3                        13.88988        72770.796875
# 5624          9.3                        13.88988        72759.257812
# 179           9.3                        13.88988        72777.296875
# 2879          9.3                         7.71660        72767.078125
# 1043          9.3                        13.88988        72771.406250
# ...           ...                             ...                 ...
# 1574          9.3                        13.88988        72776.562500
# 4949          9.3                        13.88988        72762.601562
# 377           9.3                        13.88988        72775.062500
# 2672          9.3                        13.88988        72770.093750
# 2915          9.3                        13.88988        72771.007812
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %% [markdown]
# Теперь воспользуемся robust z-score

# %%
def robust_zscore(series):
    median = series.median()
    mad = np.median(np.abs(series - median))
    # Защита от деления на ноль:
    if mad == 0:
        return pd.Series([0.0] * len(series), index=series.index)
    return (series - median) / mad

# %%
THRESHOLD = 3.5

# %%
combined_train_data_outliers_z_score = pd.DataFrame(columns=combined_train_data.columns)
for column in columns:
    rz = robust_zscore(combined_train_data[column])
    mask = np.abs(rz) > THRESHOLD

    outliers = combined_train_data[mask].index  # ← сохраняем!
    combined_train_data_outliers_z_score = pd.concat([combined_train_data_outliers_z_score, combined_train_data.loc[outliers]])
# Out:
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_103540\1144483877.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_train_data_outliers_z_score = pd.concat([combined_train_data_outliers_z_score, combined_train_data.loc[outliers]])

# %%
combined_train_data_outliers_z_score
# Out:
#        Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 11258          9.3                         7.71660        72755.132812
# 1844           9.3                        13.88988        72780.218750
# 9044           9.3                        13.88988        72770.484375
# 10601          9.3                        13.88988        72761.296875
# 2213           9.3                        13.88988        72770.796875
# ...            ...                             ...                 ...
# 3185           9.3                        13.88988        72774.570312
# 2672           9.3                        13.88988        72770.093750
# 10313          9.3                        13.88988        72755.460938
# 9917           9.3                        13.88988        72763.460938
# 2915           9.3                        13.88988        72771.007812
#
#        Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %%
intersection = combined_train_data_outliers_z_score.merge(combined_train_data_outliers, how="inner")
intersection = intersection.drop_duplicates().reset_index(drop=True)

# %%
intersection
# Out:
#      Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 0            9.3                        13.88988        72770.796875
# 1            9.3                        13.88988        72759.257812
# 2            9.3                        13.88988        72777.296875
# 3            9.3                         7.71660        72767.078125
# 4            9.3                        13.88988        72771.406250
# ..           ...                             ...                 ...
# 291          9.3                        13.88988        72776.562500
# 292          9.3                        13.88988        72762.601562
# 293          9.3                        13.88988        72775.062500
# 294          9.3                        13.88988        72770.093750
# 295          9.3                        13.88988        72771.007812
#
#      Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# 0               372.846313    9776.623047          644.765015
# ...

# %% [markdown]
# Вот и есть выбросы, которые мы удалим из train выборки.

# %%
combined_train_data
# Out:
#        Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 1996         8.206                        12.34656        50996.140625
# 11259        1.138                         7.71660         3446.263916
# 5614         8.206                        12.34656        50993.601562
# 3604         5.140                         7.71660        21633.392578
# 7288         8.206                        12.34656        50991.355469
# ...            ...                             ...                 ...
# 3046         5.140                         7.71660        21632.289062
# 9917         9.300                        13.88988        72763.460938
# 4079         3.144                         4.62996         8378.214844
# 2254         5.140                         7.71660        21636.271484
# 2915         9.300                        13.88988        72771.007812
#
#        Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %%
clean = combined_train_data.merge(
    intersection,
    how='outer',
    indicator=True
).query('_merge == "left_only"').drop(columns='_merge')

# %%
clean
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 0           1.138                         1.54332          253.546997
# 1           1.138                         1.54332          268.738007
# 2           1.138                         1.54332          276.699005
# 3           1.138                         1.54332          283.855011
# 4           1.138                         1.54332          284.459015
# ...           ...                             ...                 ...
# 9541        9.300                        13.88988        72782.164062
# 9542        9.300                        13.88988        72782.367188
# 9544        9.300                        13.88988        72782.757812
# 9545        9.300                        13.88988        72782.804688
# 9546        9.300                        13.88988        72783.335938
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %% [markdown]
# Теперь будем искать аномалии с помощью Isolation Forest, One-class SVM и DBSCAN

# %%
def draw_anomaly(X_2d: np.ndarray[float], anomaly_mask: np.ndarray[bool]) -> None:
    """Визуализация аномальных объектов

    Args:
        X_2d (np.ndarray[float]): Датасет, пониженный до двумерного пространства
        anomaly_mask (np.ndarray[bool]): Маска аномальных объектов
    """
    plt.scatter(X_2d[:, 0], X_2d[:, 1])
    plt.scatter(X_2d[anomaly_mask, 0], X_2d[anomaly_mask, 1], c="red", marker='x')

# %%
def draw_anomaly_pie(anomaly_mask: np.ndarray[bool]) -> None:
    """Визуализация долей аномальных и неаномальных объектов в данных

    Args:
        anomaly_mask (np.ndarray[bool]): Маска аномальных объектов
    """
    _, counts = np.unique(anomaly_mask, return_counts=True)

    plt.pie(counts, labels=counts, autopct='%1.0f%%');
    plt.legend([
        'Нормальные объекты', 'Аномалии'
    ], loc='lower right');

# %% [markdown]
# ### Isolation forest

# %% [markdown]
# Поскольку точной информации о том, что же является аномалией, что нет - то берем contamination (ожидаемая доля аномалий) равным 0,1.

# %%
feature_cols = clean.columns.drop('Гармония Бессмертия')
train = clean[feature_cols].values

# %%
iso_forest = IsolationForest(
    contamination=0.1,
    random_state=42,
    n_estimators=100
)

# %%
predicted_iso = iso_forest.fit_predict(train)

# %%
anomaly = (predicted_iso == -1)

# %%
anomalies_iso = clean[anomaly].copy()

# %% [markdown]
# Для визуализации уменьшим размерность до 2-х. Используем PCA.

# %%
pca = PCA(n_components=2, random_state=42)
train_2d = pca.fit_transform(train)

# %%
draw_anomaly(train_2d, anomaly)

# %% [markdown]
# *Красным помечены аномалии*

# %%
draw_anomaly_pie(anomaly)

# %% [markdown]
# Получаем 925 аномалий.

# %% [markdown]
# ### One-class SVM

# %%
ocsvm1 = OCSVM(
    kernel='rbf', # хорошо обрабатывает нелинейные связи
    nu=0.1, # верхняя оценка на долю ошибок границы и опорных векторов
)

ocsvm2 = OCSVM(
    kernel='rbf', # хорошо обрабатывает нелинейные связи
    nu=0.1, # верхняя оценка на долю ошибок границы и опорных векторов
)

# %% [markdown]
# Сделаем стандартизацию (2-мя способами)

# %%
scaler_std = StandardScaler()
train_std = scaler_std.fit_transform(train)

# %%
scaler_robust = RobustScaler()
train_robust = scaler_robust.fit_transform(train)

# %%
ocsvm1.fit(train_std)
# Out:
# OCSVM(cache_size=200, coef0=0.0, contamination=0.1, degree=3, gamma='auto',
#    kernel='rbf', max_iter=-1, nu=0.1, shrinking=True, tol=0.001,
#    verbose=False)

# %%
ocsvm2.fit(train_robust)
# Out:
# OCSVM(cache_size=200, coef0=0.0, contamination=0.1, degree=3, gamma='auto',
#    kernel='rbf', max_iter=-1, nu=0.1, shrinking=True, tol=0.001,
#    verbose=False)

# %%
predicted_ocsvm1 = ocsvm1.labels_
predicted_ocsvm2 = ocsvm2.labels_

# %%
anomaly_ocsvm1 = (predicted_ocsvm1 == 1)
anomaly_ocsvm2 = (predicted_ocsvm2 == 1)

# %%
anomalies_ocsvm1 = clean[anomaly_ocsvm1].copy()
anomalies_ocsvm2 = clean[anomaly_ocsvm2].copy()

# %%
draw_anomaly(train_2d, anomaly_ocsvm1)

# %%
draw_anomaly(train_2d, anomaly_ocsvm2)

# %%
draw_anomaly_pie(anomaly_ocsvm1)

# %%
draw_anomaly_pie(anomaly_ocsvm2)

# %% [markdown]
# Возьмем пересечение их аномалий.

# %%
intersection = anomaly_ocsvm1 & anomaly_ocsvm2
anomalies_intersection = clean[intersection]

# %%
anomalies_intersection
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 0           1.138                         1.54332          253.546997
# 1           1.138                         1.54332          268.738007
# 2           1.138                         1.54332          276.699005
# 3           1.138                         1.54332          283.855011
# 4           1.138                         1.54332          284.459015
# ...           ...                             ...                 ...
# 9541        9.300                        13.88988        72782.164062
# 9542        9.300                        13.88988        72782.367188
# 9544        9.300                        13.88988        72782.757812
# 9545        9.300                        13.88988        72782.804688
# 9546        9.300                        13.88988        72783.335938
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %%
draw_anomaly(train_2d, intersection)

# %%
draw_anomaly_pie(intersection)

# %% [markdown]
# В пересечении получаем 721 строку

# %% [markdown]
# ### DBSCAN

# %% [markdown]
# В качестве eps будем использовать среднее расстояние между точкой и её ближайшим 4-ым соседом.

# %%
eps_std = np.mean(
    NearestNeighbors(n_neighbors=5)
    .fit(train_std)
    .kneighbors()[0][:, -1]
)

# %%
eps_robust = np.mean(
    NearestNeighbors(n_neighbors=5)
    .fit(train_robust)
    .kneighbors()[0][:, -1]
)

# %%
dbscan_std = DBSCAN(eps=eps_std, min_samples=5, n_jobs=-1)
dbscan_robust = DBSCAN(eps=eps_robust, min_samples=5, n_jobs=-1)

# %%
anomaly_dbscan_std = (dbscan_std.fit_predict(train_std) == -1)
anomaly_dbscan_robust = (dbscan_robust.fit_predict(train_robust) == -1)

# %%
anomalies_dbscan_std = clean[anomaly_dbscan_std].copy()
anomalies_dbscan_robust = clean[anomaly_dbscan_robust].copy()

# %%
draw_anomaly(train_2d, anomaly_dbscan_std)

# %%
draw_anomaly_pie(anomaly_dbscan_std)

# %%
draw_anomaly(train_2d, anomaly_dbscan_robust)

# %%
draw_anomaly_pie(anomaly_dbscan_robust)

# %%
intersection_check = anomaly_dbscan_std & anomaly_dbscan_robust

# %%
anomalies_intersection = clean[intersection_check].copy()

# %%
anomalies_intersection
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 0           1.138                         1.54332          253.546997
# 1           1.138                         1.54332          268.738007
# 2           1.138                         1.54332          276.699005
# 3           1.138                         1.54332          283.855011
# 4           1.138                         1.54332          284.459015
# ...           ...                             ...                 ...
# 8582        9.300                         7.71660        72780.156250
# 8583        9.300                         7.71660        72780.585938
# 8584        9.300                         7.71660        72780.812500
# 8585        9.300                         7.71660        72782.125000
# 8586        9.300                         7.71660        72783.000000
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %% [markdown]
# Получаем 1861 строку.

# %%
draw_anomaly(train_2d, intersection_check)

# %%
draw_anomaly_pie(intersection_check)

# %% [markdown]
# ### Объединим полученные результаты

# %%
final_intersection = intersection_check & intersection & anomaly

# %%
draw_anomaly(train_2d, final_intersection)

# %%
draw_anomaly_pie(final_intersection)

# %% [markdown]
# Получаем 139 аномалий - их мы и удалим

# %%
target_col = 'Гармония Бессмертия'

# %%
data_without_anomalies = clean[~final_intersection]

# %%
X_train_clear, y_train_clear = data_without_anomalies.drop(columns=[target_col]), data_without_anomalies[target_col]
X_train_clear
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 5           1.138                         1.54332          290.028992
# 6           1.138                         1.54332          293.264008
# 7           1.138                         1.54332          301.550995
# 8           1.138                         1.54332          301.639008
# 12          1.138                         1.54332          326.338989
# ...           ...                             ...                 ...
# 9541        9.300                        13.88988        72782.164062
# 9542        9.300                        13.88988        72782.367188
# 9544        9.300                        13.88988        72782.757812
# 9545        9.300                        13.88988        72782.804688
# 9546        9.300                        13.88988        72783.335938
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %%
y_train_clear
# Out:
# 5       0.996
# 6       0.997
# 7       0.978
# 8       0.997
# 12      0.996
#         ...
# 9541    1.000
# 9542    1.000
# 9544    1.000
# 9545    1.000
# 9546    0.999
# Name: Гармония Бессмертия, Length: 9112, dtype: float64

# %% [markdown]
# ## 1.7. Подведение итогов раздела 1

# %% [markdown]
# По итогу первой главы были сделаны следующие действия:
#
#         Удалены столбцы со слишком малым количеством информации (столбцы, где одно значение преобладает над всеми остальными);
#
#         Категориальный признак преобразован по hot-encodingу;
#
#         Обработан вещественный признак с пропусками данных;
#
#         Удалены явные выбросы и аномалии (для исходных столбцов);
#
#         Данные разделены на train и test выборки.

# %% [markdown]
# # 2. Генерация новых признаков

# %%
X_train_clear['Общая мощность потоков'] = X_train_clear['Сила Правого Потока'] + X_train_clear['Сила Левого Потока']
X_train_clear['Полная мощность потоков'] = X_train_clear['Сила Правого Потока'] + X_train_clear['Сила Левого Потока'] + X_train_clear['Приток Силы Потока']
X_train_clear['Общая сила Ядра'] = X_train_clear['Ритм магического ядра'] * X_train_clear['Приток Силы Потока']
X_train_clear['Общее давление на выходе'] = X_train_clear['Приток давления Выдоха Истока'] + X_train_clear['Давление выдоха Истока']
X_train_clear['Магическая производительность'] = X_train_clear['Скорость перехода через портал'] / X_train_clear['Эмульсия Истока']
X_train_clear['Эффективность Ядра'] = X_train_clear['Общая сила Ядра'] / X_train_clear['Эмульсия Истока']

# %%
X_test['Общая мощность потоков'] = X_test['Сила Правого Потока'] + X_test['Сила Левого Потока']
X_test['Полная мощность потоков'] = X_test['Сила Правого Потока'] + X_test['Сила Левого Потока'] + X_test['Приток Силы Потока']
X_test['Общая сила Ядра'] = X_test['Ритм магического ядра'] * X_test['Приток Силы Потока']
X_test['Общее давление на выходе'] = X_test['Приток давления Выдоха Истока'] + X_test['Давление выдоха Истока']
X_test['Магическая производительность'] = X_test['Скорость перехода через портал'] / X_test['Эмульсия Истока']
X_test['Эффективность Ядра'] = X_test['Общая сила Ядра'] / X_test['Эмульсия Истока']

# %%
X_train_clear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9112 entries, 5 to 9546
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Вектор Мощи                     9112 non-null   float32
#  1   Скорость перехода через портал  9112 non-null   float32
#  2   Приток Силы Потока              9112 non-null   float32
#  3   Ритм магического ядра           9112 non-null   float32
#  4   Поток Энергий                   9112 non-null   float32
#  5   Сила Левого Потока              9112 non-null   float32
#  6   Сила Правого Потока             9112 non-null   float32
#  7   Пламя Стихий                    9112 non-null   float32
#  8   Приток давления Выдоха Истока   9112 non-null   float32
#  9   Давление выдоха Истока          9112 non-null   float32
#  10  Печать Чародея                  9112 non-null   float32
#  11  Эмульсия Истока                 9112 non-null   float32
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2387 entries, 9078 to 4862
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Вектор Мощи                     2387 non-null   float32
#  1   Скорость перехода через портал  2387 non-null   float32
#  2   Приток Силы Потока              2387 non-null   float32
#  3   Ритм магического ядра           2387 non-null   float32
#  4   Поток Энергий                   2387 non-null   float32
#  5   Сила Левого Потока              2387 non-null   float32
#  6   Сила Правого Потока             2387 non-null   float32
#  7   Пламя Стихий                    2387 non-null   float32
#  8   Приток давления Выдоха Истока   2387 non-null   float32
#  9   Давление выдоха Истока          2387 non-null   float32
#  10  Печать Чародея                  2387 non-null   float32
#  11  Эмульсия Истока                 2387 non-null   float32
# ...

# %%
X_train_clear['Тип Вектора Мощи_Ниже среднего'] = X_train_clear['Тип Вектора Мощи_Ниже среднего'].astype('int8')
X_train_clear['Тип Вектора Мощи_Сильный'] = X_train_clear['Тип Вектора Мощи_Сильный'].astype('int8')
X_train_clear['Тип Вектора Мощи_Слабый'] = X_train_clear['Тип Вектора Мощи_Слабый'].astype('int8')
X_test['Тип Вектора Мощи_Ниже среднего'] = X_test['Тип Вектора Мощи_Ниже среднего'].astype('int8')
X_test['Тип Вектора Мощи_Сильный'] = X_test['Тип Вектора Мощи_Сильный'].astype('int8')
X_test['Тип Вектора Мощи_Слабый'] = X_test['Тип Вектора Мощи_Слабый'].astype('int8')

# %% [markdown]
# ## 2.0.1 Детекция выбросов и аномалий в новых столбцах

# %%
combined_train_data = pd.concat([X_train_clear, y_train_clear], axis = 1)

# %%
cols = ['Общая мощность потоков', 'Полная мощность потоков', 'Общая сила Ядра', 'Общее давление на выходе', 'Магическая производительность', 'Эффективность Ядра']

# %%
for col in cols:
    plt.figure(figsize=(6, 4))
    plt.boxplot(combined_train_data[col].dropna(), vert=True, patch_artist=True)
    plt.title(f'Boxplot: {col}')
    plt.ylabel(col)
    plt.grid(True, axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# В признаке 'Общая сила Ядра' и 'Магическая производительность' присутствуют возможные выбросы. Поэтому в них имеет смысл использовать IQR или Robust Z-score.

# %%
combined_train_data
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 5           1.138                         1.54332          290.028992
# 6           1.138                         1.54332          293.264008
# 7           1.138                         1.54332          301.550995
# 8           1.138                         1.54332          301.639008
# 12          1.138                         1.54332          326.338989
# ...           ...                             ...                 ...
# 9541        9.300                        13.88988        72782.164062
# 9542        9.300                        13.88988        72782.367188
# 9544        9.300                        13.88988        72782.757812
# 9545        9.300                        13.88988        72782.804688
# 9546        9.300                        13.88988        72783.335938
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %%
columns = ['Общая сила Ядра', 'Магическая производительность']

# %%
combined_train_data_outliers = pd.DataFrame(columns=combined_train_data.columns)
for column in columns:
    Q1 = combined_train_data[column].quantile(0.25)
    Q3 = combined_train_data[column].quantile(0.75)
    IQR = Q3 - Q1

    # Границы выбросов
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # только выбросы
    combined_train_data_outliers = pd.concat([combined_train_data_outliers, combined_train_data[(combined_train_data[column] < lower_bound) | (combined_train_data[column] > upper_bound)]])
# Out:
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_103540\1628806345.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_train_data_outliers = pd.concat([combined_train_data_outliers, combined_train_data[(combined_train_data[column] < lower_bound) | (combined_train_data[column] > upper_bound)]])

# %%
combined_train_data_outliers
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 8550        9.300                          7.7166        72772.562500
# 8560        9.300                          7.7166        72775.578125
# 8561        9.300                          7.7166        72775.710938
# 8565        9.300                          7.7166        72776.773438
# 8573        9.300                          7.7166        72778.132812
# ...           ...                             ...                 ...
# 3171        3.144                          7.7166         8380.359375
# 3172        3.144                          7.7166         8380.627930
# 3173        3.144                          7.7166         8380.919922
# 3174        3.144                          7.7166         8381.134766
# 3175        3.144                          7.7166         8381.215820
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %%
def robust_zscore(series):
    median = series.median()
    mad = np.median(np.abs(series - median))
    # Защита от деления на ноль:
    if mad == 0:
        return pd.Series([0.0] * len(series), index=series.index)
    return (series - median) / mad

# %%
THRESHOLD = 3.5

# %%
combined_train_data_outliers_z_score = pd.DataFrame(columns=combined_train_data.columns)
for column in columns:
    rz = robust_zscore(combined_train_data[column])
    mask = np.abs(rz) > THRESHOLD

    outliers = combined_train_data[mask].index  # ← сохраняем!
    combined_train_data_outliers_z_score = pd.concat([combined_train_data_outliers_z_score, combined_train_data.loc[outliers]])
# Out:
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_103540\1144483877.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_train_data_outliers_z_score = pd.concat([combined_train_data_outliers_z_score, combined_train_data.loc[outliers]])

# %%
combined_train_data_outliers_z_score
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 7427        8.206                          7.7166        50987.921875
# 7428        8.206                          7.7166        50988.531250
# 7429        8.206                          7.7166        50989.582031
# 7430        8.206                          7.7166        50990.269531
# 7431        8.206                          7.7166        50990.531250
# ...           ...                             ...                 ...
# 3171        3.144                          7.7166         8380.359375
# 3172        3.144                          7.7166         8380.627930
# 3173        3.144                          7.7166         8380.919922
# 3174        3.144                          7.7166         8381.134766
# 3175        3.144                          7.7166         8381.215820
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %%
intersection = combined_train_data_outliers_z_score.merge(combined_train_data_outliers, how="inner")
intersection = intersection.drop_duplicates().reset_index(drop=True)

# %%
intersection
# Out:
#      Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 0          9.300                          7.7166        72772.562500
# 1          9.300                          7.7166        72775.578125
# 2          9.300                          7.7166        72775.710938
# 3          9.300                          7.7166        72776.773438
# 4          9.300                          7.7166        72778.132812
# ..           ...                             ...                 ...
# 967        3.144                          7.7166         8380.359375
# 968        3.144                          7.7166         8380.627930
# 969        3.144                          7.7166         8380.919922
# 970        3.144                          7.7166         8381.134766
# 971        3.144                          7.7166         8381.215820
#
#      Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# 0               372.845062    9755.416992          644.789001
# ...

# %%
combined_train_data
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 5           1.138                         1.54332          290.028992
# 6           1.138                         1.54332          293.264008
# 7           1.138                         1.54332          301.550995
# 8           1.138                         1.54332          301.639008
# 12          1.138                         1.54332          326.338989
# ...           ...                             ...                 ...
# 9541        9.300                        13.88988        72782.164062
# 9542        9.300                        13.88988        72782.367188
# 9544        9.300                        13.88988        72782.757812
# 9545        9.300                        13.88988        72782.804688
# 9546        9.300                        13.88988        72783.335938
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %%
clean = combined_train_data.merge(
    intersection,
    how='outer',
    indicator=True
).query('_merge == "left_only"').drop(columns='_merge')

# %%
clean
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 0           1.138                         1.54332          290.028992
# 1           1.138                         1.54332          293.264008
# 2           1.138                         1.54332          301.550995
# 3           1.138                         1.54332          301.639008
# 4           1.138                         1.54332          326.338989
# ...           ...                             ...                 ...
# 8397        8.206                        12.34656        50997.937500
# 8398        8.206                        12.34656        50997.941406
# 8399        8.206                        12.34656        50998.039062
# 8400        8.206                        12.34656        50998.050781
# 8401        8.206                        12.34656        50998.097656
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %% [markdown]
# Isolation forest

# %%
feature_cols = clean.columns.drop('Гармония Бессмертия')
train = clean[feature_cols].values

# %%
iso_forest = IsolationForest(
    contamination=0.1,
    random_state=42,
    n_estimators=100
)

# %%
predicted_iso = iso_forest.fit_predict(train)

# %%
anomaly = (predicted_iso == -1)

# %%
anomalies_iso = clean[anomaly].copy()

# %%
pca = PCA(n_components=2, random_state=42)
train_2d = pca.fit_transform(train)

# %%
draw_anomaly(train_2d, anomaly)

# %%
draw_anomaly_pie(anomaly)

# %% [markdown]
# One-class SVM

# %%
ocsvm1 = OCSVM(
    kernel='rbf', # хорошо обрабатывает нелинейные связи
    nu=0.1, # верхняя оценка на долю ошибок границы и опорных векторов
)

ocsvm2 = OCSVM(
    kernel='rbf', # хорошо обрабатывает нелинейные связи
    nu=0.1, # верхняя оценка на долю ошибок границы и опорных векторов
)

# %%
scaler_std = StandardScaler()
train_std = scaler_std.fit_transform(train)

scaler_robust = RobustScaler()
train_robust = scaler_robust.fit_transform(train)

ocsvm1.fit(train_std)

ocsvm2.fit(train_robust)

predicted_ocsvm1 = ocsvm1.labels_
predicted_ocsvm2 = ocsvm2.labels_

anomaly_ocsvm1 = (predicted_ocsvm1 == 1)
anomaly_ocsvm2 = (predicted_ocsvm2 == 1)

anomalies_ocsvm1 = clean[anomaly_ocsvm1].copy()
anomalies_ocsvm2 = clean[anomaly_ocsvm2].copy()

# %%
draw_anomaly(train_2d, anomaly_ocsvm1)

# %%
draw_anomaly(train_2d, anomaly_ocsvm2)

# %%
draw_anomaly_pie(anomaly_ocsvm1)

# %%
draw_anomaly_pie(anomaly_ocsvm2)

# %%
intersection = anomaly_ocsvm1 & anomaly_ocsvm2
anomalies_intersection = clean[intersection]

anomalies_intersection
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 0           1.138                         1.54332          290.028992
# 1           1.138                         1.54332          293.264008
# 3           1.138                         1.54332          301.639008
# 4           1.138                         1.54332          326.338989
# 5           1.138                         1.54332          338.324005
# ...           ...                             ...                 ...
# 8397        8.206                        12.34656        50997.937500
# 8398        8.206                        12.34656        50997.941406
# 8399        8.206                        12.34656        50998.039062
# 8400        8.206                        12.34656        50998.050781
# 8401        8.206                        12.34656        50998.097656
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %%
draw_anomaly(train_2d, intersection)

# %%
draw_anomaly_pie(intersection)

# %% [markdown]
# DBSCAN

# %%
eps_std = np.mean(
    NearestNeighbors(n_neighbors=5)
    .fit(train_std)
    .kneighbors()[0][:, -1]
)

eps_robust = np.mean(
    NearestNeighbors(n_neighbors=5)
    .fit(train_robust)
    .kneighbors()[0][:, -1]
)

# %%
dbscan_std = DBSCAN(eps=eps_std, min_samples=5, n_jobs=-1)
dbscan_robust = DBSCAN(eps=eps_robust, min_samples=5, n_jobs=-1)

anomaly_dbscan_std = (dbscan_std.fit_predict(train_std) == -1)
anomaly_dbscan_robust = (dbscan_robust.fit_predict(train_robust) == -1)

anomalies_dbscan_std = clean[anomaly_dbscan_std].copy()
anomalies_dbscan_robust = clean[anomaly_dbscan_robust].copy()

# %%
draw_anomaly(train_2d, anomaly_dbscan_std)

# %%
draw_anomaly_pie(anomaly_dbscan_std)

# %%
draw_anomaly(train_2d, anomaly_dbscan_robust)

# %%
draw_anomaly_pie(anomaly_dbscan_robust)

# %%
intersection_check = anomaly_dbscan_std & anomaly_dbscan_robust

# %%
anomalies_intersection = clean[intersection_check].copy()

# %%
anomalies_intersection
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 0           1.138                         1.54332          290.028992
# 1           1.138                         1.54332          293.264008
# 2           1.138                         1.54332          301.550995
# 3           1.138                         1.54332          301.639008
# 4           1.138                         1.54332          326.338989
# ...           ...                             ...                 ...
# 7438        8.206                         7.71660        50996.531250
# 7439        8.206                         7.71660        50996.562500
# 7440        8.206                         7.71660        50996.761719
# 7441        8.206                         7.71660        50996.910156
# 7442        8.206                         7.71660        50997.164062
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %%
draw_anomaly(train_2d, intersection_check)

# %%
draw_anomaly_pie(intersection_check)

# %%
final_intersection = intersection_check & intersection & anomaly

# %%
draw_anomaly(train_2d, final_intersection)

# %%
draw_anomaly_pie(final_intersection)

# %%
target_col = 'Гармония Бессмертия'

# %%
data_without_anomalies = clean[~final_intersection]

# %%
X_train_clear, y_train_clear = data_without_anomalies.drop(columns=[target_col]), data_without_anomalies[target_col]
X_train_clear
# Out:
#       Вектор Мощи  Скорость перехода через портал  Приток Силы Потока  \
# 2           1.138                         1.54332          301.550995
# 8           1.138                         1.54332          356.795013
# 9           1.138                         1.54332          357.487000
# 10          1.138                         1.54332          362.010986
# 11          1.138                         1.54332          385.161987
# ...           ...                             ...                 ...
# 8397        8.206                        12.34656        50997.937500
# 8398        8.206                        12.34656        50997.941406
# 8399        8.206                        12.34656        50998.039062
# 8400        8.206                        12.34656        50998.050781
# 8401        8.206                        12.34656        50998.097656
#
#       Ритм магического ядра  Поток Энергий  Сила Левого Потока  \
# ...

# %%
y_train_clear
# Out:
# 2       0.978
# 8       0.977
# 9       0.980
# 10      0.997
# 11      0.982
#         ...
# 8397    0.982
# 8398    0.983
# 8399    0.982
# 8400    0.980
# 8401    0.981
# Name: Гармония Бессмертия, Length: 7945, dtype: float64

# %% [markdown]
# ## 2.0.2 Проверка бесконечных значений в test выборке (и в train выборке)

# %% [markdown]
# Также проверим (на всякий случай) есть ли в данных (в новых столбцах) бесконечности или Nanы.

# %%
print(f"NaN: {X_test.isna().sum().sum()}")
print(f"Inf: {np.isinf(X_test.select_dtypes(include=[np.number])).sum().sum()}")
# Out:
# NaN: 0
# Inf: 0

# %%
print(f"NaN: {X_train_clear.isna().sum().sum()}")
print(f"Inf: {np.isinf(X_train_clear.select_dtypes(include=[np.number])).sum().sum()}")
# Out:
# NaN: 0
# Inf: 0

# %% [markdown]
# ## 2.1. Корреляционный анализ входных признаков (построение тепловых карт корреляции)

# %%
correlation_matrix = X_train_clear.corr()

# %%
plt.figure(figsize=(16, 16))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# Заметим очень сильную корреляцию между многими признаками. Также заметен один признак, который вообще ни от чего не зависит ("Дыхание истока"). Поэтому попробуем менять признаки так, чтобы корреляция между ними становилась "нормальной". Однако, стоит понимать, чем больше мы будем "менять" признаки, тем больше вероятность того, что они станут похожими на "Дыхание истока". Проблема данного столбца в том, что дисперсия в нем минимальна - то есть в этом столбце практически все значения одинаковы => ни от какого-либо столбца не зависят. Менять столбцы мы будем с помощью различных формул.

# %% [markdown]
# ## 2.2. Исправление проблемы мультиколлинеарности в данных

# %%
for i in X_train_clear.columns:
    print(f"Столбец: {i}")
    print(X_train_clear[i].describe())
    print("КОНЕЦ")
# Out:
# Столбец: Вектор Мощи
# count    7945.000000
# mean        4.793601
# std         2.256489
# min         1.138000
# 25%         3.144000
# 50%         5.140000
# 75%         7.148000
# max         8.206000
# Name: Вектор Мощи, dtype: float64
# КОНЕЦ
# Столбец: Скорость перехода через портал
# count    7945.000000
# mean        7.098688
# std         3.382583
# min         1.543320
# 25%         4.629960
# 50%         7.716600
# 75%         9.259920
# max        12.346560
# Name: Скорость перехода через портал, dtype: float64
# КОНЕЦ
# Столбец: Приток Силы Потока
# count     7945.000000
# mean     22353.505859
# std      15944.428711
# min        301.550995
# 25%       8375.784180
# 50%      21625.837891
# 75%      38978.203125
# max      50998.097656
# Name: Приток Силы Потока, dtype: float64
# КОНЕЦ
# Столбец: Ритм магического ядра
# count    7945.000000
# mean      207.976593
# std        64.902092
# min       137.119308
# 25%       145.221069
# 50%       201.513687
# ...

# %% [markdown]
# Сначала возьмем признаки с минимальной дисперсией и сделаем из них пару. На их основе сделаем третий признак и заменим один из двух. Это Приток давления Выдоха Истока и Эмульсия истока. Столбец Дыхание истока было решено не брать, поскольку он имеет почти константное значение. Поэтому пока мы оставим его как есть. Чуть позже решим - удалить или оставить.

# %%
X_generating = X_train_clear.copy()
X_test_generating = X_test.copy()

# %% [markdown]
# Назовем его СМД_0... (Столбец минимальной дисперсии)

# %%
X_generating['СМД_01'] = np.sqrt((X_generating['Приток давления Выдоха Истока']**2 + X_generating['Эмульсия Истока']**2)/2)
X_generating['СМД_02'] = (X_generating['Приток давления Выдоха Истока']**2 * X_generating['Эмульсия Истока']**2)/ 4
X_generating['СМД_03'] = X_generating['Приток давления Выдоха Истока'] / (X_generating['Эмульсия Истока'])

# %%
X_test_generating['СМД_01'] = np.sqrt((X_test_generating['Приток давления Выдоха Истока']**2 + X_test_generating['Эмульсия Истока']**2)/2)
X_test_generating['СМД_02'] = (X_test_generating['Приток давления Выдоха Истока']**2 * X_test_generating['Эмульсия Истока']**2)/ 4
X_test_generating['СМД_03'] = X_test_generating['Приток давления Выдоха Истока'] / (X_test_generating['Эмульсия Истока'])

# %%
correlation_matrix = X_generating[['СМД_01','СМД_02','СМД_03' ,'Приток давления Выдоха Истока', 'Эмульсия Истока']].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
print(correlation_matrix)
# Out:
#                                  СМД_01    СМД_02    СМД_03  \
# СМД_01                         1.000000  0.890615 -0.763853
# СМД_02                         0.890615  1.000000 -0.550425
# СМД_03                        -0.763853 -0.550425  1.000000
# Приток давления Выдоха Истока  0.999933  0.885785 -0.765629
# Эмульсия Истока                0.996520  0.913885 -0.770094
#
#                                Приток давления Выдоха Истока  Эмульсия Истока
# СМД_01                                              0.999933         0.996520
# СМД_02                                              0.885785         0.913885
# СМД_03                                             -0.765629        -0.770094
# Приток давления Выдоха Истока                       1.000000         0.995579
# Эмульсия Истока                                     0.995579         1.000000

# %% [markdown]
# Берем СМД_02 и СМД_03 (все остальные сильно коррелируют друг с другом)

# %%
X_generating = X_generating.drop(columns=['Приток давления Выдоха Истока', 'Эмульсия Истока', 'СМД_01'])
X_test_generating = X_test_generating.drop(columns=['Приток давления Выдоха Истока', 'Эмульсия Истока', 'СМД_01'])

# %%
correlation_matrix = X_generating.corr()
plt.figure(figsize=(16, 16))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# Берем следующие несколько столбцов. *На данном шаге, конечно, надо было бы использовать другие варианты выбора столбцов для замены, НО...* В процессе исследования данных, была замечена ОЧЕНЬ странная связь между 3-мя столбцами: 'Сила Правого Потока', 'Сила Левого Потока'. Поэтому проверим их столбцы (столбцы, с которыми связаны они)

# %%
correlation_matrix = X_generating[['Общая мощность потоков', 'Сила Правого Потока', 'Сила Левого Потока']].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
print((X_generating['Сила Левого Потока'] == X_generating['Сила Правого Потока']).all())
# Out:
# True

# %% [markdown]
# Мы получаем, что силы идентичны => и корреляция равна 1. Поэтому смело удаляем 2 из 3 признаков. Оставим Общую мощность потоков

# %%
X_generating = X_generating.drop(columns=['Сила Правого Потока', 'Сила Левого Потока'])
X_test_generating = X_test_generating.drop(columns=['Сила Правого Потока', 'Сила Левого Потока'])

# %%
correlation_matrix = X_generating.corr()
plt.figure(figsize=(16, 16))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# Здесь стоит обратить внимание также на 'Полная мощность потоков', который связан линейно с двумя признаками: 'Общая мощность потоков' и 'Приток Силы Потока'

# %%
correlation_matrix = X_generating[['Общая мощность потоков', 'Приток Силы Потока', 'Полная мощность потоков']].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# Создаем различные комбинации данных признаков. Точнее комбинации 'Общая мощность потоков' и 'Приток Силы Потока'.

# %%
X_generating['умножение мощности на приток'] = X_generating['Приток Силы Потока'] * X_generating['Общая мощность потоков']
X_generating['разница квадратов мощности и притока'] = X_generating['Приток Силы Потока']**2 - X_generating['Общая мощность потоков']**2
X_generating['взвещенные мощность и приток'] = X_generating['Приток Силы Потока']*0.3 - X_generating['Общая мощность потоков']*0.7
X_generating['триг комбинация мощности и притока'] = np.sin(X_generating['Приток Силы Потока']) - np.sin(X_generating['Общая мощность потоков'])
X_generating['разница мощности и притока в кубе'] = (X_generating['Приток Силы Потока'] - X_generating['Общая мощность потоков'])**3
X_generating['Лог асимметрия мощности и притока'] = np.log(X_generating['Приток Силы Потока']**2) - np.log(X_generating['Общая мощность потоков']**2)

# %%
X_test_generating['умножение мощности на приток'] = X_test_generating['Приток Силы Потока'] * X_test_generating['Общая мощность потоков']
X_test_generating['разница квадратов мощности и притока'] = X_test_generating['Приток Силы Потока']**2 - X_test_generating['Общая мощность потоков']**2
X_test_generating['взвещенные мощность и приток'] = X_test_generating['Приток Силы Потока']*0.3 - X_test_generating['Общая мощность потоков']*0.7
X_test_generating['триг комбинация мощности и притока'] = np.sin(X_test_generating['Приток Силы Потока']) - np.sin(X_test_generating['Общая мощность потоков'])
X_test_generating['разница мощности и притока в кубе'] = (X_test_generating['Приток Силы Потока'] - X_test_generating['Общая мощность потоков'])**3
X_test_generating['Лог асимметрия мощности и притока'] = np.log(X_test_generating['Приток Силы Потока']**2) - np.log(X_test_generating['Общая мощность потоков']**2)

# %%
correlation_matrix = X_generating[['Лог асимметрия мощности и притока', 'разница мощности и притока в кубе', 'триг комбинация мощности и притока', 'взвещенные мощность и приток', 'разница квадратов мощности и притока', 'умножение мощности на приток', 'Общая мощность потоков', 'Приток Силы Потока', 'Полная мощность потоков']].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
print(correlation_matrix)
# Out:
#                                       Лог асимметрия мощности и притока  \
# Лог асимметрия мощности и притока                              1.000000
# разница мощности и притока в кубе                             -0.333666
# триг комбинация мощности и притока                             0.025694
# взвещенные мощность и приток                                  -0.479737
# разница квадратов мощности и притока                          -0.396188
# умножение мощности на приток                                  -0.395279
# Общая мощность потоков                                        -0.513165
# Приток Силы Потока                                            -0.481152
# Полная мощность потоков                                       -0.481722
#
#                                       разница мощности и притока в кубе  \
# Лог асимметрия мощности и притока                             -0.333666
# разница мощности и притока в кубе                              1.000000
# ...

# %%
X_generating['триг комбинация мощности и притока'].describe()
# Out:
# count    7945.000000
# mean       -0.212021
# std         1.112569
# min        -1.996245
# 25%        -1.167369
# 50%        -0.133331
# 75%         0.479540
# max         1.999562
# Name: триг комбинация мощности и притока, dtype: float64

# %%
X_generating['Лог асимметрия мощности и притока'].describe()
# Out:
# count    7945.000000
# mean        8.514125
# std         0.749236
# min         6.127232
# 25%         8.144313
# 50%         8.244837
# 75%         8.480238
# max        12.389030
# Name: Лог асимметрия мощности и притока, dtype: float64

# %% [markdown]
# Берем 'Лог асимметрия мощности и притока', 'триг комбинация мощности и притока' и 'Полная мощность потоков'

# %%
correlation_matrix = X_generating[['Лог асимметрия мощности и притока', 'триг комбинация мощности и притока','Полная мощность потоков']].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
X_generating = X_generating.drop(columns=['разница мощности и притока в кубе', 'взвещенные мощность и приток', 'разница квадратов мощности и притока', 'умножение мощности на приток', 'Общая мощность потоков', 'Приток Силы Потока'])
X_test_generating = X_test_generating.drop(columns=['разница мощности и притока в кубе', 'взвещенные мощность и приток', 'разница квадратов мощности и притока', 'умножение мощности на приток', 'Общая мощность потоков', 'Приток Силы Потока'])

# %% [markdown]
# Идем дальше...

# %%
correlation_matrix = X_generating.corr()
plt.figure(figsize=(16, 16))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# На данном шаге "идеи" кончились и начался простой анализ самых коррелирующих признаков.

# %%
def get_high_correlations(df, threshold=0.7):
    corr_matrix = df.corr()
    high_corr_pairs = []
    for i in range(len(corr_matrix.columns)):
        for j in range(i+1, len(corr_matrix.columns)):
            corr = corr_matrix.iloc[i, j]
            if abs(corr) > threshold:
                col1 = corr_matrix.columns[i]
                col2 = corr_matrix.columns[j]
                high_corr_pairs.append((col1, col2, corr))
    high_corr_pairs.sort(key=lambda x: abs(x[2]), reverse=True)
    return high_corr_pairs

# %%
high_corr = get_high_correlations(X_generating, threshold=0.75)

# %%
for col1, col2, corr in high_corr:
    print(f"{col1} - {col2}: {corr}")
# Out:
# Давление выдоха Истока - Общее давление на выходе: 0.9999898796203404
# Полная мощность потоков - Общее давление на выходе: 0.9988768900086187
# Давление выдоха Истока - Полная мощность потоков: 0.998818674624801
# Ритм магического ядра - Общее давление на выходе: 0.9953621476653804
# Ритм магического ядра - Давление выдоха Истока: 0.9951611212656113
# Вектор Мощи - Эффективность Ядра: 0.9944800486687265
# Ритм магического ядра - Полная мощность потоков: 0.9912205064506658
# Ритм магического ядра - Общая сила Ядра: 0.987762262206211
# Пламя Стихий - Полная мощность потоков: 0.9877352704729967
# Общая сила Ядра - Общее давление на выходе: 0.9863097051160012
# Пламя Стихий - Давление выдоха Истока: 0.9862284227107981
# Пламя Стихий - Общее давление на выходе: 0.9858953768038692
# Давление выдоха Истока - Общая сила Ядра: 0.985735464593564
# Полная мощность потоков - Общая сила Ядра: 0.9855854362140136
# Поток Энергий - Эффективность Ядра: 0.9854447487862515
# ...

# %% [markdown]
# Попробуем разобраться с первой тройкой: Давление выдоха истока, общее давление на выдохе, полная мощность потоков

# %% [markdown]
# Проверим их на "повторяемость"

# %%
equal_count = (X_generating['Давление выдоха Истока'] == X_generating['Общее давление на выходе']).sum()
print(equal_count)
# Out:
# 0

# %%
equal_count = (X_generating['Полная мощность потоков'] == X_generating['Общее давление на выходе']).sum()
print(equal_count)
# Out:
# 0

# %%
equal_count = (X_generating['Полная мощность потоков'] == X_generating['Давление выдоха Истока']).sum()
print(equal_count)
# Out:
# 0

# %% [markdown]
# Поскольку мы пользовались полной мощностью потоков, то мы оставим данный столбец в любом случае.

# %%
X_generating['Синус разности давления выдоха и общего давления на выход'] = np.sin(X_generating['Давление выдоха Истока'] - X_generating['Общее давление на выходе'])
X_generating['Лог давления выдоха и общего давления на выход'] = np.log(X_generating['Давление выдоха Истока']) - np.log(X_generating['Общее давление на выходе']) 
X_generating['Гиперболический тангенс давления выдоха и общего давления на выход'] = (X_generating['Давление выдоха Истока'] - X_generating['Общее давление на выходе']) \
    / (X_generating['Давление выдоха Истока'].std() + X_generating['Общее давление на выходе'].std()) * 3
X_generating['разность относительно медиан'] = (X_generating['Давление выдоха Истока']/X_generating['Давление выдоха Истока'].median()) - \
    (X_generating['Общее давление на выходе']/X_generating['Общее давление на выходе'].median())
X_generating['усиленная тангенс разность'] = np.tanh(X_generating['Гиперболический тангенс давления выдоха и общего давления на выход'])

# %%
X_test_generating['Синус разности давления выдоха и общего давления на выход'] = np.sin(X_test_generating['Давление выдоха Истока'] - X_test_generating['Общее давление на выходе'])
X_test_generating['Лог давления выдоха и общего давления на выход'] = np.log(X_test_generating['Давление выдоха Истока']) - np.log(X_test_generating['Общее давление на выходе']) 
X_test_generating['Гиперболический тангенс давления выдоха и общего давления на выход'] = (X_test_generating['Давление выдоха Истока'] - X_test_generating['Общее давление на выходе']) \
    / (X_test_generating['Давление выдоха Истока'].std() + X_test_generating['Общее давление на выходе'].std()) * 3
X_test_generating['разность относительно медиан'] = (X_test_generating['Давление выдоха Истока']/X_test_generating['Давление выдоха Истока'].median()) - \
    (X_test_generating['Общее давление на выходе']/X_test_generating['Общее давление на выходе'].median())
X_test_generating['усиленная тангенс разность'] = np.tanh(X_test_generating['Гиперболический тангенс давления выдоха и общего давления на выход'])

# %%
correlation_matrix = X_generating[['усиленная тангенс разность', 'разность относительно медиан', 'Гиперболический тангенс давления выдоха и общего давления на выход', 'Лог давления выдоха и общего давления на выход', 'Полная мощность потоков','Давление выдоха Истока','Общее давление на выходе','Синус разности давления выдоха и общего давления на выход']].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
print(correlation_matrix)
# Out:
#                                                     усиленная тангенс разность  \
# усиленная тангенс разность                                            1.000000
# разность относительно медиан                                          0.816343
# Гиперболический тангенс давления выдоха и общег...                    0.990607
# Лог давления выдоха и общего давления на выход                        0.888587
# Полная мощность потоков                                              -0.992027
# Давление выдоха Истока                                               -0.992782
# Общее давление на выходе                                             -0.992473
# Синус разности давления выдоха и общего давлени...                   -0.882530
#
#                                                     разность относительно медиан  \
# усиленная тангенс разность                                              0.816343
# разность относительно медиан                                            1.000000
# ...

# %% [markdown]
# При исследовании значений, я решил *просто удалить* два других столбца, поскольку убрать мультиколлениарность просто не получается - в случае удаления мультиколлениарности признаки становятся константными - о чем говорилось в САМОМ начала работы с признаками.

# %%
X_generating[['Полная мощность потоков', 'разность относительно медиан', 'Лог давления выдоха и общего давления на выход']].describe()
# Out:
#        Полная мощность потоков  разность относительно медиан  \
# count              7945.000000                   7945.000000
# mean              22718.126953                     -0.000195
# std               16228.238281                      0.003260
# min                 315.639008                     -0.010247
# 25%                8496.416016                     -0.001486
# 50%               21976.322266                      0.001082
# 75%               39642.406250                      0.002038
# max               51874.207031                      0.003563
#
#        Лог давления выдоха и общего давления на выход
# count                                     7945.000000
# mean                                        -0.172508
# std                                          0.002744
# min                                         -0.179372
# 25%                                         -0.174371
# 50%                                         -0.171868
# ...

# %%
X_generating[['усиленная тангенс разность', 'разность относительно медиан', 'Гиперболический тангенс давления выдоха и общего давления на выход', 'Лог давления выдоха и общего давления на выход', 'Полная мощность потоков','Давление выдоха Истока','Общее давление на выходе','Синус разности давления выдоха и общего давления на выход']].describe()
# Out:
#        усиленная тангенс разность  разность относительно медиан  \
# count                 7945.000000                   7945.000000
# mean                    -0.583667                     -0.000195
# std                      0.158606                      0.003260
# min                     -0.836101                     -0.010247
# 25%                     -0.756794                     -0.001486
# 50%                     -0.601192                      0.001082
# 75%                     -0.433799                      0.002038
# max                     -0.350694                      0.003563
#
#        Гиперболический тангенс давления выдоха и общего давления на выход  \
# count                                        7945.000000
# mean                                           -0.709637
# std                                             0.270452
# min                                            -1.208075
# 25%                                            -0.988669
# ...

# %%
X_generating = X_generating.drop(columns=['усиленная тангенс разность', 'разность относительно медиан', 'Гиперболический тангенс давления выдоха и общего давления на выход', 'Лог давления выдоха и общего давления на выход','Давление выдоха Истока','Общее давление на выходе','Синус разности давления выдоха и общего давления на выход'])
X_test_generating = X_test_generating.drop(columns=['усиленная тангенс разность', 'разность относительно медиан', 'Гиперболический тангенс давления выдоха и общего давления на выход', 'Лог давления выдоха и общего давления на выход','Давление выдоха Истока','Общее давление на выходе','Синус разности давления выдоха и общего давления на выход'])

# %%
correlation_matrix = X_generating.corr()
plt.figure(figsize=(16, 16))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# То есть мы просто оставили 'Полная мощность потоков'

# %% [markdown]
# Смотрим дальше

# %%
high_corr = get_high_correlations(X_generating, threshold=0.79)
for col1, col2, corr in high_corr:
    print(f"{col1} - {col2}: {corr}")
# Out:
# Вектор Мощи - Эффективность Ядра: 0.9944800486687265
# Ритм магического ядра - Полная мощность потоков: 0.9912205064506658
# Ритм магического ядра - Общая сила Ядра: 0.987762262206211
# Пламя Стихий - Полная мощность потоков: 0.9877352704729967
# Полная мощность потоков - Общая сила Ядра: 0.9855854362140136
# Поток Энергий - Эффективность Ядра: 0.9854447487862515
# Вектор Мощи - Скорость перехода через портал: 0.9850726830762564
# Вектор Мощи - Поток Энергий: 0.9827601485800344
# Скорость перехода через портал - Эффективность Ядра: 0.9786669940613749
# Полная мощность потоков - Эффективность Ядра: 0.9781135544164201
# Вектор Мощи - Полная мощность потоков: 0.9764078264242217
# Ритм магического ядра - Пламя Стихий: 0.9714510143201244
# Пламя Стихий - Эффективность Ядра: 0.9713429397800581
# Вектор Мощи - Пламя Стихий: 0.9687707958673325
# Скорость перехода через портал - Поток Энергий: 0.9682133955784445
# Печать Чародея - Общая сила Ядра: 0.9631193637165063
# ...

# %% [markdown]
# Возьмем два признака: 'Ритм магического ядра', 'Общая сила Ядра' - они много с "кем" коррелируют очень сильно.

# %%
correlation_matrix = X_generating[['Ритм магического ядра', 'Общая сила Ядра']].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
X_generating['Ритм магического ядра'].describe()
# Out:
# count    7945.000000
# mean      207.976593
# std        64.902092
# min       137.119308
# 25%       145.221069
# 50%       201.513687
# 75%       280.438568
# max       323.336578
# Name: Ритм магического ядра, dtype: float64

# %%
X_generating['Общая сила Ядра'].describe()
# Out:
# count    7.945000e+03
# mean     5.674584e+06
# std      5.350074e+06
# min      4.232421e+04
# 25%      1.216323e+06
# 50%      4.357929e+06
# 75%      1.093136e+07
# max      1.648955e+07
# Name: Общая сила Ядра, dtype: float64

# %% [markdown]
# Добавляем еще признаков!

# %%
X_generating['произведение ритма и силы'] = X_generating['Ритм магического ядра'] * X_generating['Общая сила Ядра']
X_generating['разность ритма и силы'] = X_generating['Ритм магического ядра'] - X_generating['Общая сила Ядра']
X_generating['лог сила ядра'] = np.log(X_generating['Общая сила Ядра'])

# %%
X_test_generating['произведение ритма и силы'] = X_test_generating['Ритм магического ядра'] * X_test_generating['Общая сила Ядра']
X_test_generating['разность ритма и силы'] = X_test_generating['Ритм магического ядра'] - X_test_generating['Общая сила Ядра']
X_test_generating['лог сила ядра'] = np.log(X_test_generating['Общая сила Ядра'])

# %%
correlation_matrix = X_generating[['лог сила ядра', 'разность ритма и силы', 'произведение ритма и силы', 'Ритм магического ядра', 'Общая сила Ядра']].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
X_generating['лог сила ядра'].describe()
# Out:
# count    7945.000000
# mean       14.936930
# std         1.260608
# min        10.653114
# 25%        14.011343
# 50%        15.287508
# 75%        16.207146
# max        16.618237
# Name: лог сила ядра, dtype: float64

# %%
X_generating['произведение ритма и силы'].describe()
# Out:
# count    7.945000e+03
# mean     1.523119e+09
# std      1.751276e+09
# min      5.940416e+06
# 25%      1.766331e+08
# 50%      8.781893e+08
# 75%      3.065675e+09
# max      5.331675e+09
# Name: произведение ритма и силы, dtype: float64

# %%
correlation_matrix
# Out:
#                            лог сила ядра  разность ритма и силы  \
# лог сила ядра                   1.000000              -0.884800
# разность ритма и силы          -0.884800               1.000000
# произведение ритма и силы       0.829664              -0.992800
# Ритм магического ядра           0.911344              -0.987762
# Общая сила Ядра                 0.884801              -1.000000
#
#                            произведение ритма и силы  Ритм магического ядра  \
# лог сила ядра                               0.829664               0.911344
# разность ритма и силы                      -0.992800              -0.987762
# произведение ритма и силы                   1.000000               0.965022
# Ритм магического ядра                       0.965022               1.000000
# Общая сила Ядра                             0.992800               0.987762
#
#                            Общая сила Ядра
# лог сила ядра                     0.884801
# ...

# %% [markdown]
# Берем лог силу ядра и произведение ритма и силы

# %%
X_generating = X_generating.drop(columns=['разность ритма и силы', 'Ритм магического ядра', 'Общая сила Ядра'])
X_test_generating = X_test_generating.drop(columns=['разность ритма и силы', 'Ритм магического ядра', 'Общая сила Ядра'])

# %% [markdown]
# Идем еще дальше.......

# %%
correlation_matrix = X_generating.corr()
plt.figure(figsize=(16, 16))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
high_corr = get_high_correlations(X_generating, threshold=0.79)
for col1, col2, corr in high_corr:
    print(f"{col1} - {col2}: {corr}")
# Out:
# Вектор Мощи - Эффективность Ядра: 0.9944800486687265
# Пламя Стихий - Полная мощность потоков: 0.9877352704729967
# Поток Энергий - Эффективность Ядра: 0.9854447487862515
# Вектор Мощи - Скорость перехода через портал: 0.9850726830762564
# Эффективность Ядра - лог сила ядра: 0.9834978915328018
# Вектор Мощи - Поток Энергий: 0.9827601485800344
# Скорость перехода через портал - Эффективность Ядра: 0.9786669940613749
# Полная мощность потоков - Эффективность Ядра: 0.9781135544164201
# Вектор Мощи - лог сила ядра: 0.9770766267146358
# Вектор Мощи - Полная мощность потоков: 0.9764078264242217
# СМД_02 - произведение ритма и силы: 0.9733107628808251
# Пламя Стихий - Эффективность Ядра: 0.9713429397800581
# Поток Энергий - лог сила ядра: 0.9705155130383509
# Вектор Мощи - Пламя Стихий: 0.9687707958673325
# Скорость перехода через портал - Поток Энергий: 0.9682133955784445
# Пламя Стихий - лог сила ядра: 0.9649739625135447
# Скорость перехода через портал - лог сила ядра: 0.964327764899597
# ...

# %% [markdown]
# Теперь "поборемся" c "вектором мощи" и "эффективностью ядра"!!!

# %%
X_generating['Вектор Мощи'].describe()
# Out:
# count    7945.000000
# mean        4.793601
# std         2.256489
# min         1.138000
# 25%         3.144000
# 50%         5.140000
# 75%         7.148000
# max         8.206000
# Name: Вектор Мощи, dtype: float64

# %%
X_generating['Эффективность Ядра'].describe()
# Out:
# count    7.945000e+03
# mean     8.205580e+06
# std      3.866582e+06
# min      4.755529e+05
# 25%      4.906569e+06
# 50%      8.615643e+06
# 75%      1.221735e+07
# max      1.433627e+07
# Name: Эффективность Ядра, dtype: float64

# %%
X_generating['лог эффективность ядра'] = np.log(X_generating['Эффективность Ядра'])
X_generating['отношение лог к квадрату вектора'] = X_generating['лог эффективность ядра'] / X_generating['Вектор Мощи']**2

# %%
X_test_generating['лог эффективность ядра'] = np.log(X_test_generating['Эффективность Ядра'])
X_test_generating['отношение лог к квадрату вектора'] = X_test_generating['лог эффективность ядра'] / X_test_generating['Вектор Мощи']**2

# %%
correlation_matrix = X_generating[['отношение лог к квадрату вектора', 'Вектор Мощи', 'лог эффективность ядра', 'Эффективность Ядра']].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
correlation_matrix
# Out:
#                                   отношение лог к квадрату вектора  \
# отношение лог к квадрату вектора                          1.000000
# Вектор Мощи                                              -0.732846
# лог эффективность ядра                                   -0.808240
# Эффективность Ядра                                       -0.695812
#
#                                   Вектор Мощи  лог эффективность ядра  \
# отношение лог к квадрату вектора    -0.732846               -0.808240
# Вектор Мощи                          1.000000                0.954027
# лог эффективность ядра               0.954027                1.000000
# Эффективность Ядра                   0.994480                0.960175
#
#                                   Эффективность Ядра
# отношение лог к квадрату вектора           -0.695812
# Вектор Мощи                                 0.994480
# лог эффективность ядра                      0.960175
# Эффективность Ядра                          1.000000

# %% [markdown]
# Оставляем Эффективность и лог эффективность

# %%
X_generating = X_generating.drop(columns=['Вектор Мощи', 'лог эффективность ядра'])
X_test_generating = X_test_generating.drop(columns=['Вектор Мощи', 'лог эффективность ядра'])

# %%
correlation_matrix = X_generating.corr()
plt.figure(figsize=(16, 16))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
high_corr = get_high_correlations(X_generating, threshold=0.79)
for col1, col2, corr in high_corr:
    print(f"{col1} - {col2}: {corr}")
# Out:
# Пламя Стихий - Полная мощность потоков: 0.9877352704729967
# Поток Энергий - Эффективность Ядра: 0.9854447487862515
# Эффективность Ядра - лог сила ядра: 0.9834978915328018
# Скорость перехода через портал - Эффективность Ядра: 0.9786669940613749
# Полная мощность потоков - Эффективность Ядра: 0.9781135544164201
# СМД_02 - произведение ритма и силы: 0.9733107628808251
# Пламя Стихий - Эффективность Ядра: 0.9713429397800581
# Поток Энергий - лог сила ядра: 0.9705155130383509
# Скорость перехода через портал - Поток Энергий: 0.9682133955784445
# Пламя Стихий - лог сила ядра: 0.9649739625135447
# Скорость перехода через портал - лог сила ядра: 0.964327764899597
# Печать Чародея - Полная мощность потоков: 0.9610325662056526
# Полная мощность потоков - произведение ритма и силы: 0.9589960587187353
# Скорость перехода через портал - Полная мощность потоков: 0.9579801399052751
# Поток Энергий - Пламя Стихий: 0.9524692679684937
# Поток Энергий - Полная мощность потоков: 0.9523380202770021
# ...

# %% [markdown]
# Пытаемся поменять "Пламя стихий" - он очень часто появляется в списке коррелирующих с другими.

# %%
X_generating['Пламя Стихий'].describe()
# Out:
# count    7945.000000
# mean      699.385437
# std       130.364899
# min       448.299011
# 25%       588.453003
# 50%       696.486023
# 75%       806.036011
# max       952.122009
# Name: Пламя Стихий, dtype: float64

# %%
X_generating['логарифм пламени стихий деленный на эффективность ядра'] = np.log(X_generating['Пламя Стихий'])/ X_generating['Эффективность Ядра']

# %%
X_test_generating['логарифм пламени стихий деленный на эффективность ядра'] = np.log(X_test_generating['Пламя Стихий'])/ X_test_generating['Эффективность Ядра']

# %%
correlation_matrix = X_generating[['логарифм пламени стихий деленный на эффективность ядра', 'Пламя Стихий', 'Полная мощность потоков', 'Эффективность Ядра', 'лог сила ядра']].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
correlation_matrix
# Out:
#                                                     логарифм пламени стихий деленный на эффективность ядра  \
# логарифм пламени стихий деленный на эффективнос...                                           1.000000
# Пламя Стихий                                                                                -0.701744
# Полная мощность потоков                                                                     -0.665578
# Эффективность Ядра                                                                          -0.761071
# лог сила ядра                                                                               -0.835822
#
#                                                     Пламя Стихий  \
# логарифм пламени стихий деленный на эффективнос...     -0.701744
# Пламя Стихий                                            1.000000
# Полная мощность потоков                                 0.987735
# Эффективность Ядра                                      0.971343
# ...

# %% [markdown]
# Меняем пламя стихий на логарифм пламени...

# %%
X_generating = X_generating.drop(columns=['Пламя Стихий'])
X_test_generating = X_test_generating.drop(columns=['Пламя Стихий'])

# %%
correlation_matrix = X_generating.corr()
plt.figure(figsize=(16, 16))
sns.heatmap(correlation_matrix)
plt.title('Корреляционная матрица признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# На данном шаге мы уже получаем куда лучшую картину!

# %% [markdown]
# Конечно, можно было бы и дальше "менять" признаки, однако!!! Вспомним одно замечание в начале работы с признаками: чем больше мы "играемся" признаками, тем больше они превращаются в константное поле, которое НИ ОТ ЧЕГО не зависит.

# %% [markdown]
# Осталось только убрать Дыхание истока.

# %%
X_generating = X_generating.drop(columns=['Дыхание Истока'])
X_test_generating = X_test_generating.drop(columns=['Дыхание Истока'])

# %%
print(correlation_matrix)
# Out:
#                                                     Скорость перехода через портал  \
# Скорость перехода через портал                                            1.000000
# Поток Энергий                                                             0.968213
# Печать Чародея                                                            0.903048
# Дыхание Истока                                                           -0.040734
# Тип Вектора Мощи_Ниже среднего                                           -0.264852
# Тип Вектора Мощи_Сильный                                                  0.731205
# Тип Вектора Мощи_Слабый                                                  -0.742515
# Полная мощность потоков                                                   0.957980
# Магическая производительность                                            -0.306345
# Эффективность Ядра                                                        0.978667
# ...

# %% [markdown]
# ## 2.3. Скалирование данных и использование метода главных компонент

# %%
from sklearn.preprocessing import RobustScaler

# %%
scaler_generating = RobustScaler()

# %%
for col in ['Тип Вектора Мощи_Ниже среднего', 'Тип Вектора Мощи_Сильный', 'Тип Вектора Мощи_Слабый']:
    X_generating[col] = X_generating[col].astype('int16')
    X_test_generating[col] = X_test_generating[col].astype('int16')

# %%
scaler_generating.fit(X_generating)
# Out:
# RobustScaler()

# %%
X_train_generating_scaled = X_generating.copy()
X_test_generating_scaled = X_test_generating.copy()

# %%
X_train_generating_scaled = scaler_generating.transform(X_generating)
X_test_generating_scaled = scaler_generating.transform(X_test_generating)

# %%
X_train_generating_scaled = pd.DataFrame(
    X_train_generating_scaled, 
    columns=X_generating.columns, 
    index=X_generating.index     
)

# %%
X_test_generating_scaled = pd.DataFrame(
    X_test_generating_scaled, 
    columns=X_test_generating.columns, 
    index=X_test_generating.index     
)

# %%
X_test_generating_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2387 entries, 9078 to 4862
# Data columns (total 17 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Скорость перехода через портал                          2387 non-null   float32
#  1   Поток Энергий                                           2387 non-null   float32
#  2   Печать Чародея                                          2387 non-null   float32
#  3   Тип Вектора Мощи_Ниже среднего                          2387 non-null   float32
#  4   Тип Вектора Мощи_Сильный                                2387 non-null   float32
#  5   Тип Вектора Мощи_Слабый                                 2387 non-null   float32
#  6   Полная мощность потоков                                 2387 non-null   float32
#  7   Магическая производительность                           2387 non-null   float32
# ...

# %%
X_train_generating_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7945 entries, 2 to 8401
# Data columns (total 17 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Скорость перехода через портал                          7945 non-null   float32
#  1   Поток Энергий                                           7945 non-null   float32
#  2   Печать Чародея                                          7945 non-null   float32
#  3   Тип Вектора Мощи_Ниже среднего                          7945 non-null   float32
#  4   Тип Вектора Мощи_Сильный                                7945 non-null   float32
#  5   Тип Вектора Мощи_Слабый                                 7945 non-null   float32
#  6   Полная мощность потоков                                 7945 non-null   float32
#  7   Магическая производительность                           7945 non-null   float32
# ...

# %% [markdown]
# ## 2.4. Подведение итогов раздела 2

# %% [markdown]
# В рамках 2-го раздела были получены следующие результаты:
#
#         В некоторой степени была убрана мультиколлениарность (убрать её полностью, используя только замену столбцов нельзя - иначе будут столбцы-константы)
#
#         Масштабированы данные

# %% [markdown]
# # 3. Выбор моделей ML и метрик

# %% [markdown]
# Выбираем 3 модели, которые оптимальны для этих данных:
#
# 1. GradientBoosting (LightGBM)
#    Градиентные бустинг был выбран по следующим причинам: устойчивость к переобучению, интерпретируемость и быстрая скорость обучения;
# 2. Support Vector Regression (SVR)
#    SVR был выбран по следующим причинам:  устойчивость к выбросам и гибкость через ядра;
# 3. Elastic Net
#    Elastic Net был выбран по следующим причинам: простота и скорость, интерпретируемость и регуляризация.

# %% [markdown]
# Как работает Gradient Boosting?
#
# Он строит ансамбль деревьев решений последовательно:
#
# 1. Начинает с простого предсказания (например, среднее значение целевой переменной);
# 2. Вычисляет ошибки (градиенты) для каждого объекта;
# 3. Строит дерево, которое лучше всего предсказывает эти ошибки;
# 4. Добавляет это дерево к ансамблю с небольшим весом (learning rate);
# 5. Повторяет шаги 2 - 4 много-много раз (100-1000 итераций).

# %% [markdown]
# Как работает SVR?
#
# Он пытается найти функцию f(x), которая отклоняется от истинных значений не более чем на e:
# 1. Создаёт е-трубку: допустимая область ошибок вокруг истинных значений;
# 2. Минимизирует ширину трубки: Ищет самую "плоскую" функцию, которая помещает все точки в трубку;
# 3. Разрешает ошибки: точки вне трубки штрафуются параметром C;
# 4. Использует трюк с ядром: для нелинейных зависимостей отображает данные в пространство более высокой размерности.

# %% [markdown]
# Как работает Elastic Net?
#
# Это линейная модель с комбинированной регуляцией:
# 1. Линейная комбинация: y_pred = w1*PCA1 + w2*PCA2 + w3*PCA3 + b;
# 2. Минимизация ошибки: Обычная MSE или MAE;
# 3. Добавление регуляризации: L1 (Lasso) - обнуляет неважные коэффициенты, L2 (Ridge) - уменьшает величину коэффициентов
# 4. Баланс регуляризаций: Параметр a контролирует соотношение L1/L2.

# %% [markdown]
# Используем следующие метрики:
# 1. MAE (Mean Absolute Error) - Средняя абсолютная ошибка
#    Формула MAE = (1/n) * sum(|y_true - y_pred|) - средняя величина ошибки в абсолютных единицах измерения целевой переменной. Выбрал поскольку она проста в интерпретации и сохраняет единицы измерения.
# 2. MSE (Mean Squared Error) - Средняя квадратичная ошибка
#    Формула MSE = (1/n) * sum((y_true - y_pred)^2). Также будем использовать RSME (Root MSE): RMSE = sqrt(MSE) - средний квадрат ошибок (корень из среднего квадрата ошибок). Выбрал т.к. она сильнее штрафует за ошибки и чувствительна к выбросам.
# 3. R^2 - Коэффициент детерминации
#    Формула R^2 = 1 - (sum((y_true - y_pred)^2) / sum((y_true - y_mean)^2)), где y_mean - среднее значение целевой переменной. Она показывает долю объясненной дисперсии целевой переменной. Выбрал из-за масштабируемости, сравнимости (с помощью неё можно сравнивать модели между собой) и интерпретируемости.
# 4. MAPE (Mean Absolute Percentage Error) - Средняя абсолютная процентная ошибка Формула MAPE = (1/n) * sum(|(y_true - y_pred) / y_true|) * 100%. Она показывает среднюю ошибку в процентах от истинного значения. Выбрал так как легко интерпретируема. (НЕ РАБОТАЕТ ДЛЯ НУЛЕВЫХ ЗНАЧЕНИЙ ЦЕЛЕВОЙ ПЕРЕМЕННОЙ)

# %% [markdown]
# Для обучения в Optuna выберу R^2, так как она удобна для сравнения моделей и легко интерпретируема. Остальные метрики имеют значительные недостатки: MAE - пропускает закономерности (хотя и устойчива к выбросам - хотя мы их заранее почистили), MSE - гиперчувствительна к ошибкам, MAPE - может создать смещенные прогнозы.

# %%
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.linear_model import ElasticNet

# %%
lgbm_params = {
    'n_estimators': [100, 200, 300],       
    'learning_rate': [0.01, 0.05, 0.1],     
    'max_depth': [3, 5, 7, 10]
}

svr_params = {
    'C': [0.1, 1.0, 10.0, 100.0],       
    'epsilon': [0.01, 0.1, 0.2, 0.5],    
    'kernel': ['rbf', 'poly'], 
    'gamma': ['scale', 'auto', 0.01, 0.1, 1.0]
}

elastic_params = {
    'alpha': [0.001, 0.01, 0.1, 1.0, 10.0],     
    'l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9, 1.0],  
    'max_iter': [1000, 2000, 5000],  
    'tol': [1e-4, 1e-3, 1e-2], 
    'selection': ['cyclic', 'random']
}

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

# %% [markdown]
# # 4. Обучение моделей ML и подбор гиперпараметров

# %%
for col in ['Тип Вектора Мощи_Ниже среднего', 'Тип Вектора Мощи_Сильный', 'Тип Вектора Мощи_Слабый']:
    X_train_clear[col] = X_train_clear[col].astype('int16')
    X_test[col] = X_test[col].astype('int16')

# %%
import optuna
from sklearn.model_selection import cross_val_score

# %%
X_test_current =  X_test_generating_scaled
X_train_current = X_train_generating_scaled
y_train_current = y_train_clear
y_test_current = y_test

# %%
def objective_lgbm(trial, param_grid, X_train, y_train):
    params = {
        'n_estimators': trial.suggest_categorical('n_estimators', param_grid['n_estimators']),
        'learning_rate': trial.suggest_categorical('learning_rate', param_grid['learning_rate']),
        'max_depth': trial.suggest_categorical('max_depth', param_grid['max_depth']),
    }
    
    model = LGBMRegressor(**params, random_state=42, verbose=-1)
    scores = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')
    return scores.mean()

def objective_svr(trial, param_grid, X_train, y_train):
    params = {
        'C': trial.suggest_categorical('C', param_grid['C']),
        'epsilon': trial.suggest_categorical('epsilon', param_grid['epsilon']),
        'kernel': trial.suggest_categorical('kernel', param_grid['kernel']),
        'gamma': trial.suggest_categorical('gamma', param_grid['gamma']),
    }
    
    model = SVR(**params)
    scores = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')
    return scores.mean()

def objective_elastic(trial, param_grid, X_train, y_train):
    params = {
        'alpha': trial.suggest_categorical('alpha', param_grid['alpha']),
        'l1_ratio': trial.suggest_categorical('l1_ratio', param_grid['l1_ratio']),
        'max_iter': trial.suggest_categorical('max_iter', param_grid['max_iter']),
        'tol': trial.suggest_categorical('tol', param_grid['tol']),
        'selection': trial.suggest_categorical('selection', param_grid['selection']),
    }
    
    model = ElasticNet(**params, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')
    return scores.mean()

# %%
lgbm = optuna.create_study(direction='maximize')
lgbm.optimize(lambda trial: objective_lgbm(trial, lgbm_params, X_train_current, y_train_current), n_trials=20)
# Out:
# [I 2026-01-07 01:21:47,201] A new study created in memory with name: no-name-0a9540c7-ae81-43d3-b7b5-3af1c6056d21
# [I 2026-01-07 01:21:47,948] Trial 0 finished with value: -0.11519982473954202 and parameters: {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 7}. Best is trial 0 with value: -0.11519982473954202.
# [I 2026-01-07 01:21:48,269] Trial 1 finished with value: -0.20897315529416952 and parameters: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5}. Best is trial 0 with value: -0.11519982473954202.
# [I 2026-01-07 01:21:48,707] Trial 2 finished with value: -0.12499710701050089 and parameters: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 7}. Best is trial 0 with value: -0.11519982473954202.
# [I 2026-01-07 01:21:48,921] Trial 3 finished with value: -0.19126849542796895 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 5}. Best is trial 0 with value: -0.11519982473954202.
# ...

# %%
svr = optuna.create_study(direction='maximize')
svr.optimize(lambda trial: objective_svr(trial, svr_params, X_train_current, y_train_current), n_trials=10)
# Out:
# [I 2026-01-07 01:21:53,750] A new study created in memory with name: no-name-0a973fc3-1d6f-4d6a-94af-1a13c25f4da4
# [I 2026-01-07 01:21:53,780] Trial 0 finished with value: -0.002665184588056535 and parameters: {'C': 1.0, 'epsilon': 0.5, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 0 with value: -0.002665184588056535.
# [I 2026-01-07 01:21:54,129] Trial 1 finished with value: -0.7609890418885191 and parameters: {'C': 100.0, 'epsilon': 0.01, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: -0.002665184588056535.
# [I 2026-01-07 01:21:54,152] Trial 2 finished with value: -0.002665184588056535 and parameters: {'C': 10.0, 'epsilon': 0.2, 'kernel': 'rbf', 'gamma': 1.0}. Best is trial 0 with value: -0.002665184588056535.
# [I 2026-01-07 01:21:54,171] Trial 3 finished with value: -0.002665184588056535 and parameters: {'C': 100.0, 'epsilon': 0.5, 'kernel': 'poly', 'gamma': 0.01}. Best is trial 0 with value: -0.002665184588056535.
# ...

# %%
elastic = optuna.create_study(direction='maximize')
elastic.optimize(lambda trial: objective_elastic(trial, elastic_params, X_train_current, y_train_current), n_trials=20)
# Out:
# [I 2026-01-07 01:22:00,621] A new study created in memory with name: no-name-41824c09-fb51-4b27-9727-fd65b48e6b27
# [I 2026-01-07 01:22:00,651] Trial 0 finished with value: -0.004163286367387409 and parameters: {'alpha': 0.01, 'l1_ratio': 0.5, 'max_iter': 1000, 'tol': 0.001, 'selection': 'random'}. Best is trial 0 with value: -0.004163286367387409.
# [I 2026-01-07 01:22:00,674] Trial 1 finished with value: -0.004163286367387409 and parameters: {'alpha': 10.0, 'l1_ratio': 0.5, 'max_iter': 5000, 'tol': 0.0001, 'selection': 'random'}. Best is trial 0 with value: -0.004163286367387409.
# [I 2026-01-07 01:22:00,694] Trial 2 finished with value: -0.004163286367387409 and parameters: {'alpha': 0.01, 'l1_ratio': 0.9, 'max_iter': 5000, 'tol': 0.01, 'selection': 'random'}. Best is trial 0 with value: -0.004163286367387409.
# ...

# %%
best_lgbm = LGBMRegressor(**lgbm.best_params, random_state=42, verbose=-1)

# %%
best_svr = SVR(**svr.best_params)

# %%
best_elastic = ElasticNet(**elastic.best_params, random_state=42)

# %% [markdown]
# На данном этапе можно сказать, что фактически результат работы разочаровывает, поскольку длительная работа с данными к существенным изменениям так и не привела...

# %% [markdown]
# Проверим обучение на "прошлых выборках" - SVR уберем, поскольку он не работает на "крупных значениях"

# %%
lgbm = optuna.create_study(direction='maximize')
lgbm.optimize(lambda trial: objective_lgbm(trial, lgbm_params, X_train_clear, y_train_clear), n_trials=20)
# Out:
# [I 2026-01-07 01:22:01,122] A new study created in memory with name: no-name-fc460464-1747-454c-a951-efa0e57cd0bb
# [I 2026-01-07 01:22:01,686] Trial 0 finished with value: -0.393810335628605 and parameters: {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 5}. Best is trial 0 with value: -0.393810335628605.
# [I 2026-01-07 01:22:02,004] Trial 1 finished with value: -0.1930269642000022 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 10}. Best is trial 1 with value: -0.1930269642000022.
# [I 2026-01-07 01:22:02,500] Trial 2 finished with value: -0.2915796513602624 and parameters: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7}. Best is trial 1 with value: -0.1930269642000022.
# [I 2026-01-07 01:22:02,786] Trial 3 finished with value: -0.3221580112347072 and parameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 7}. Best is trial 1 with value: -0.1930269642000022.
# ...

# %%
elastic = optuna.create_study(direction='maximize')
elastic.optimize(lambda trial: objective_elastic(trial, elastic_params, X_train_clear, y_train_clear), n_trials=30)
# Out:
# [I 2026-01-07 01:22:07,682] A new study created in memory with name: no-name-607bffb6-19cd-4060-adc1-2d4cec09242c
# c:\Projects_Visual_Studio_Code\Practicum_5_semester\my_venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.224e-01, tolerance: 3.573e-05
#   model = cd_fast.enet_coordinate_descent(
# c:\Projects_Visual_Studio_Code\Practicum_5_semester\my_venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.391e-01, tolerance: 3.545e-05
#   model = cd_fast.enet_coordinate_descent(
# ...

# %% [markdown]
# То есть на "чистых данных" Elastic Net может выдавать куда лучшие значения, чем после преобразования наших признаков.

# %% [markdown]
# Теперь на X_generating

# %%
lgbm = optuna.create_study(direction='maximize')
lgbm.optimize(lambda trial: objective_lgbm(trial, lgbm_params, X_generating , y_train_clear), n_trials=20)
# Out:
# [I 2026-01-07 01:22:14,722] A new study created in memory with name: no-name-6090eeb2-9f84-4a00-aa83-4a8bb8e01211
# [I 2026-01-07 01:22:14,988] Trial 0 finished with value: -0.26225661681576623 and parameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5}. Best is trial 0 with value: -0.26225661681576623.
# [I 2026-01-07 01:22:15,716] Trial 1 finished with value: -0.13443948480237905 and parameters: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 10}. Best is trial 1 with value: -0.13443948480237905.
# [I 2026-01-07 01:22:16,121] Trial 2 finished with value: -0.11698509130669774 and parameters: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 5}. Best is trial 2 with value: -0.11698509130669774.
# [I 2026-01-07 01:22:16,819] Trial 3 finished with value: -0.12066484965610566 and parameters: {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 10}. Best is trial 2 with value: -0.11698509130669774.
# ...

# %%
elastic = optuna.create_study(direction='maximize')
elastic.optimize(lambda trial: objective_elastic(trial, elastic_params, X_generating , y_train_clear), n_trials=30)
# Out:
# [I 2026-01-07 01:22:21,359] A new study created in memory with name: no-name-b49a94d4-721a-4a25-ad33-744ec380aed9
# c:\Projects_Visual_Studio_Code\Practicum_5_semester\my_venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.243e-01, tolerance: 3.573e-04
#   model = cd_fast.enet_coordinate_descent(
# c:\Projects_Visual_Studio_Code\Practicum_5_semester\my_venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.400e-01, tolerance: 3.545e-04
#   model = cd_fast.enet_coordinate_descent(
# ...

# %% [markdown]
# Данные обучения были сделаны просто для самопроверки того, на каком шаге были допущены ошибки в данных.

# %% [markdown]
# Получается, ошибки появились скорее после генерации признаков, точнее при замене признаков другими.

# %% [markdown]
# # 5. Вычисление метрик на новых данных

# %%
best_lgbm.fit(X_train_current, y_train_current)
y_pred_lgbm_train = best_lgbm.predict(X_train_current)
y_pred_lgbm_test = best_lgbm.predict(X_test_current)

print("LightGBM:")
print(f"  Train R²: {r2_score(y_train_current, y_pred_lgbm_train):.4f}")
print(f"  Test  R²: {r2_score(y_test_current, y_pred_lgbm_test):.4f}")
print(f"  Test MSE: {mean_squared_error(y_test_current, y_pred_lgbm_test):.6f}")
print(f"  Test MAE: {mean_absolute_error(y_test_current, y_pred_lgbm_test):.6f}")
print(f"  Test MAPE: {np.sqrt(mean_absolute_percentage_error(y_test_current, y_pred_lgbm_test)):.6f}")
print()

best_svr.fit(X_train_current, y_train_current)
y_pred_svr_train = best_svr.predict(X_train_current)
y_pred_svr_test = best_svr.predict(X_test_current)

print("SVR:")
print(f"  Train R²: {r2_score(y_train_current, y_pred_svr_train):.4f}")
print(f"  Test  R²: {r2_score(y_test_current, y_pred_svr_test):.4f}")
print(f"  Test MSE: {mean_squared_error(y_test_current, y_pred_svr_test):.6f}")
print(f"  Test MAE: {mean_absolute_error(y_test_current, y_pred_svr_test):.6f}")
print(f"  Test MAPE: {np.sqrt(mean_absolute_percentage_error(y_test_current, y_pred_svr_test)):.6f}")
print()

best_elastic.fit(X_train_current, y_train_current)
y_pred_elastic_train = best_elastic.predict(X_train_current)
y_pred_elastic_test = best_elastic.predict(X_test_current)

print("ElasticNet:")
print(f"  Train R²: {r2_score(y_train_current, y_pred_elastic_train):.4f}")
print(f"  Test  R²: {r2_score(y_test_current, y_pred_elastic_test):.4f}")
print(f"  Test MSE: {mean_squared_error(y_test_current, y_pred_elastic_test):.6f}")
print(f"  Test MAE: {mean_absolute_error(y_test_current, y_pred_elastic_test):.6f}")
print(f"  Test MAPE: {np.sqrt(mean_absolute_percentage_error(y_test_current, y_pred_elastic_test)):.6f}")
# Out:
# LightGBM:
#   Train R²: 0.2514
#   Test  R²: 0.1884
#   Test MSE: 0.000046
#   Test MAE: 0.005815
#   Test MAPE: 0.076726
#
# SVR:
#   Train R²: 0.4870
#   Test  R²: 0.3960
#   Test MSE: 0.000034
#   Test MAE: 0.004942
#   Test MAPE: 0.070757
#
# ElasticNet:
#   Train R²: -0.0000
#   Test  R²: -0.0002
#   Test MSE: 0.000057
#   Test MAE: 0.006572
#   Test MAPE: 0.081590

# %% [markdown]
# # 6. Результат работы

# %% [markdown]
# | Модель      | Train R² | Test R² | Test MSE   | Test MAE | Test MAPE  |
# |-------------|----------|---------|------------|----------|------------|
# | LightGBM    | 0.2514   | 0.1884  | 0.000046   | 0.005815 | 0.076726   |
# | SVR         | 0.4870   | 0.3960  | 0.000034   | 0.004942 | 0.070757   |
# | ElasticNet  | -0.0000  | -0.0002 | 0.000057   | 0.006572 | 0.081590   |

# %% [markdown]
# Достаточно странно, но мы получаем весьма неплохие данные для SVR - с учётом того, что мы видели при обучении модели при помощи optuna.

# %% [markdown]
# Конечно, результат домашней работы далёк от идеала. Скорее всего неправильным решением было удалять признаки с достаточно большими значениями (около 300-400) из данных. В следуюший раз лучшим решением будет не трогать их. Скорее всего, во время выполнения именно генерации признаков были допущены "роковые" ошибки в данных. Однако, на основе таких "не очень хороших" результатов, можно сказать, что SVR показал себя лучше всех остальных. LightGBM оказался вторым, а Elastic не смог нормально выдавать результаты.
